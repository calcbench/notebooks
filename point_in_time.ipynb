# %%
import calcbench as cb
import pandas as pd
from datetime import date, datetime

# %%
cb.api_client._rig_for_testing()

# %%
as_of_date = date(2013, 1, 1)

# %%
tickers = cb.tickers(index='DJIA')
data = cb.normalized_dataframe(company_identifiers=tickers, 
                                metrics=['filing_date', 'revenue', 'marketcapatendofperiod'],
                                start_year=2009, start_period=0, end_year=2016, end_period=0,
                                   point_in_time=True)
# Out:
# c:\users\andrew kittredge\appdata\local\programs\python\python35\lib\site-packages\requests\packages\urllib3\connectionpool.py:791: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# c:\users\andrew kittredge\appdata\local\programs\python\python35\lib\site-packages\requests\packages\urllib3\connectionpool.py:791: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)

# %%
point_in_time_mask = data.filing_date.apply(lambda col: col < as_of_date)

# %%
data[point_in_time_mask]
# Out:
# metric marketcapatendofperiod                                            \
# ticker                    AXP            BA           CAT          CSCO
# period
# 2009             4.829984e+10  5.479370e+10  3.560165e+10           NaN
# 2010             5.137524e+10  6.606017e+10  5.983001e+10  1.304608e+11
# 2011             5.490588e+10  7.424935e+10  5.866350e+10  8.679695e+10
# 2012                      NaN           NaN           NaN  8.312562e+10
# 2013                      NaN           NaN           NaN           NaN
# 2014                      NaN           NaN           NaN           NaN
# 2015                      NaN           NaN           NaN           NaN
#
# metric                                                                        \
# ticker           CVX            DD           DIS            GE            GS
# period
# 2009    1.546231e+11           NaN  5.074694e+10  1.613323e+11  8.697183e+10
# 2010    1.831798e+11           NaN  6.313208e+10  1.941552e+11  8.534638e+10
# 2011    2.103492e+11  4.267854e+10  5.418284e+10  1.893627e+11  4.390083e+10
# 2012             NaN           NaN  9.264654e+10           NaN           NaN
# 2013             NaN           NaN           NaN           NaN           NaN
# 2014             NaN           NaN           NaN           NaN           NaN
# 2015             NaN           NaN           NaN           NaN           NaN
#
# metric                    ...            revenue                              \
# ticker            HD      ...                PFE            PG             T
# period                    ...
# 2009    4.756098e+10      ...       5.000900e+10  7.893800e+10  1.230180e+11
# 2010    5.640790e+10      ...       6.780900e+10  8.255900e+10  1.242800e+11
# 2011    6.896519e+10      ...       6.742500e+10  8.368000e+10  1.267230e+11
# 2012             NaN      ...                NaN           NaN           NaN
# 2013             NaN      ...                NaN           NaN           NaN
# 2014             NaN      ...                NaN           NaN           NaN
# 2015             NaN      ...                NaN           NaN           NaN
#
# metric                                                                        \
# ticker           TRV           UNH           UTX             V            VZ
# period
# 2009    2.468000e+10  8.713800e+10  5.292000e+10  6.911000e+09  1.078080e+11
# 2010    2.511200e+10  9.415500e+10  5.432600e+10  8.065000e+09  1.065650e+11
# 2011    2.544600e+10  1.018620e+11  5.819000e+10  9.188000e+09  1.108750e+11
# 2012             NaN           NaN           NaN  1.042100e+10           NaN
# 2013             NaN           NaN           NaN           NaN           NaN
# 2014             NaN           NaN           NaN           NaN           NaN
# 2015             NaN           NaN           NaN           NaN           NaN
#
# metric
# ticker           WMT           XOM
# period
# 2009    4.082140e+11  3.015000e+11
# 2010    4.218490e+11  3.701250e+11
# 2011    4.469500e+11  4.670290e+11
# 2012             NaN           NaN
# 2013             NaN           NaN
# 2014             NaN           NaN
# 2015             NaN           NaN
#
# [7 rows x 90 columns]
