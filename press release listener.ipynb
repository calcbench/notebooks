# %%
import calcbench as cb

# %%
def handle_filing(filing):
    if(filing['is_wire']):
        print(f"{filing['ticker']}, {filing['document_type']}, {filing['filing_type']}")
        pr_data = cb.press_release_raw(company_identifiers=filing['ticker'], 
                                   year=filing['fiscal_year'], 
                                   period=['fiscal_year'],
                                   match_to_previous_period=True, 
                                   standardize_beginning_of_period=True)
        print(pr_data)

# %%
cb.handle_filings(handle_filing, queue_subscription)
# Out:
# C:\Users\Andrew Kittredge\git\python_api_client\calcbench\listener.py:37: UserWarning: 'document_type'
#   warnings.warn(str(e))
# SGRP, WIREPR, 3
# None
# TSSI, WIREPR, 3
# None
# SPIN, WIREPR, 3
# None
# AIPT, WIREPR, 3
# None
# QRHC, WIREPR, 3
# None
# EFOI, WIREPR, 3
# None
# MFON, WIREPR, 3
# None
# SKAS, WIREPR, 3
# None
# DRYS, WIREPR, 3
# None
# SITO, WIREPR, 3
# None
# BRFH, WIREPR, 3
# None
# FORD, WIREPR, 3
# None
# EVOL, WIREPR, 3
# None
# LMB, WIREPR, 3
# None
# PYDS, WIREPR, 3
# None
# OMEX, WIREPR, 3
# None
# CSSE, WIREPR, 3
# None
# DDS, WIREPR, 3
# None
# CAPC, WIREPR, 3
# None
# SIEB, WIREPR, 3
# None
# XSPA, WIREPR, 3
# None
# EVC, WIREPR, 3
# None
# PETZ, WIREPR, 3
# None
# KGJI, WIREPR, 3
# None
# SNES, WIREPR, 3
# None
# IVOB, WIREPR, 3
# None
# MITO, WIREPR, 3
# None
# ACHV, WIREPR, 3
# None
# JMDA, WIREPR, 3
# None
# BHTG, WIREPR, 3
# None
# TTNP, WIREPR, 3
# None
# TCI, WIREPR, 3
# None
# UNAM, WIREPR, 3
# None
# ARL, WIREPR, 3
# None
# GLOW, WIREPR, 3
# None
# SLS, WIREPR, 3
# None
# PEYE, WIREPR, 3
# None
# SORL, WIREPR, 3
# None
# RSSS, WIREPR, 3
# None
# PHUN, WIREPR, 3
# None
# SRAX, WIREPR, 3
# None
# ACFN, WIREPR, 3
# None
# IOR, WIREPR, 3
# None
# ANY, WIREPR, 3
# None
# GBR, WIREPR, 3
# None
# FLO, WIREPR, 3
# None
# SBSAA, WIREPR, 3
# None
# NSYS, WIREPR, 3
# None
# HEBT, WIREPR, 3
# None
# CHCI, WIREPR, 3
# None
# ALC, WIREPR, 3
# None
# FPPP, WIREPR, 3
# None
# TANH, WIREPR, 3
# None
# RVP, WIREPR, 3
# None
# HCMC, WIREPR, 3
# None
# DL, WIREPR, 3
# None
# NTES, WIREPR, 3
# None
# FTLF, WIREPR, 3
# None
# ATH, WIREPR, 3
# None
# JE, WIREPR, 3
# None
# WIX, WIREPR, 3
# None
# YI, WIREPR, 3
# None
# NICE, WIREPR, 3
# None
# ZXAIY, WIREPR, 3
# None
# EXP, WIREPR, 3
# None
# MANU, WIREPR, 3
# None
# BPTH, WIREPR, 3
# None
# NHLD, WIREPR, 3
# None
# TRU, WIREPR, 3
# None
# HCCC, WIREPR, 3
# None
# KEM, WIREPR, 3
# None
# IEA, WIREPR, 3
# None
# ROX, WIREPR, 3
# None
# NXTD, WIREPR, 3
# None
# SPEX, WIREPR, 3
# None
# HEB, WIREPR, 3
# None
# BOXL, WIREPR, 3
# None
# ZEAL, WIREPR, 3
# None
# LMFA, WIREPR, 3
# None
# DIGP, WIREPR, 3
# None
# SPCB, WIREPR, 3
# None
# SNFCA, WIREPR, 3
# None
# INIS, WIREPR, 3
# None

# %%
cb.press_release_raw(company_identifiers=['wdc'], year=2019, period=1, match_to_previous_period=True, standardize_beginning_of_period=True)
# Out:
# [{'fact_id': 281485785,
#   'sec_filing_id': 1202255,
#   'effective_value': None,
#   'reported_value': None,
#   'entity_id': 675,
#   'fiscal_year': None,
#   'fiscal_period': None,
#   'UOM': '',
#   'qname_id_min': 5869233,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': 1,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'WESTERN DIGITAL ANNOUNCES FINANCIAL RESULTS FOR',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': -1,
#   'column_index': 1,
#   'extract_tag': '',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': None,
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485740,
#   'sec_filing_id': 1202255,
#   'effective_value': 5000000000.0,
#   'reported_value': 5000000000.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD',
#   'qname_id_min': 0,
#   'period_start': '2018-06-28T00:00:00',
#   'period_end': '2018-09-28T00:00:00',
#   'period_instant': None,
#   'presentation_order': 2,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'revenue',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 1,
#   'extract_tag': 'Revenu',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485740',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485741,
#   'sec_filing_id': 1202255,
#   'effective_value': 686000000.0,
#   'reported_value': 686000000.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD',
#   'qname_id_min': 0,
#   'period_start': '2018-06-28T00:00:00',
#   'period_end': '2018-09-28T00:00:00',
#   'period_instant': None,
#   'presentation_order': 3,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'Operating income',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 1,
#   'extract_tag': 'OperIncom',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485741',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485742,
#   'sec_filing_id': 1202255,
#   'effective_value': 511000000.0,
#   'reported_value': 511000000.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD',
#   'qname_id_min': 0,
#   'period_start': '2018-06-28T00:00:00',
#   'period_end': '2018-09-28T00:00:00',
#   'period_instant': None,
#   'presentation_order': 3,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'net income',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 2,
#   'extract_tag': 'Incom',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485742',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485743,
#   'sec_filing_id': 1202255,
#   'effective_value': 1.71,
#   'reported_value': 1.71,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD/shares',
#   'qname_id_min': 0,
#   'period_start': '2018-06-28T00:00:00',
#   'period_end': '2018-09-28T00:00:00',
#   'period_instant': None,
#   'presentation_order': 3,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'net income per share.',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 3,
#   'extract_tag': 'IncomPerShare',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485743',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485744,
#   'sec_filing_id': 1202255,
#   'effective_value': 1100000000.0,
#   'reported_value': 1100000000.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD',
#   'qname_id_min': 4150986,
#   'period_start': '2018-06-28T00:00:00',
#   'period_end': '2018-09-28T00:00:00',
#   'period_instant': None,
#   'presentation_order': 4,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'non-GAAP operating income',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 1,
#   'extract_tag': 'NongaapOperIncom',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': True,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485744',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485745,
#   'sec_filing_id': 1202255,
#   'effective_value': 906000000.0,
#   'reported_value': 906000000.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD',
#   'qname_id_min': 4150986,
#   'period_start': '2018-06-28T00:00:00',
#   'period_end': '2018-09-28T00:00:00',
#   'period_instant': None,
#   'presentation_order': 4,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'non-GAAP net income',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 2,
#   'extract_tag': 'NongaapNetIncom',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': True,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485745',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485746,
#   'sec_filing_id': 1202255,
#   'effective_value': 3.04,
#   'reported_value': 3.04,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD/shares',
#   'qname_id_min': 4150986,
#   'period_start': '2018-06-28T00:00:00',
#   'period_end': '2018-09-28T00:00:00',
#   'period_instant': None,
#   'presentation_order': 4,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'non-GAAP net income per share.',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 3,
#   'extract_tag': 'NongaapNetIncomPerShare',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': True,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485746',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485747,
#   'sec_filing_id': 1202255,
#   'effective_value': 5200000000.0,
#   'reported_value': 5200000000.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD',
#   'qname_id_min': 0,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': 5,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'revenue',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 1,
#   'extract_tag': 'Revenu',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485747',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485748,
#   'sec_filing_id': 1202255,
#   'effective_value': 905000000.0,
#   'reported_value': 905000000.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD',
#   'qname_id_min': 0,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': 5,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'operating income',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 2,
#   'extract_tag': 'OperIncom',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485748',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485749,
#   'sec_filing_id': 1202255,
#   'effective_value': 681000000.0,
#   'reported_value': 681000000.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD',
#   'qname_id_min': 0,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': 5,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'net income',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 3,
#   'extract_tag': 'Incom',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485749',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485750,
#   'sec_filing_id': 1202255,
#   'effective_value': 2.23,
#   'reported_value': 2.23,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD/shares',
#   'qname_id_min': 0,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': 5,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'net income per share.',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 4,
#   'extract_tag': 'IncomPerShare',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485750',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485751,
#   'sec_filing_id': 1202255,
#   'effective_value': 1400000000.0,
#   'reported_value': 1400000000.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD',
#   'qname_id_min': 4150986,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': 6,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'Non-GAAP operating income in',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 1,
#   'extract_tag': 'NongaapOperIncom',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': True,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485751',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485752,
#   'sec_filing_id': 1202255,
#   'effective_value': 1100000000.0,
#   'reported_value': 1100000000.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD',
#   'qname_id_min': 4150986,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': 6,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'non-GAAP net income',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 2,
#   'extract_tag': 'NongaapNetIncom',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': True,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485752',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485753,
#   'sec_filing_id': 1202255,
#   'effective_value': 3.56,
#   'reported_value': 3.56,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD/shares',
#   'qname_id_min': 4150986,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': 6,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'non-GAAP net income per share.',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 3,
#   'extract_tag': 'NongaapNetIncomPerShare',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': True,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485753',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485754,
#   'sec_filing_id': 1202255,
#   'effective_value': 705000000.0,
#   'reported_value': 705000000.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD',
#   'qname_id_min': 0,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': 7,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'cash from operations - generated',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 1,
#   'extract_tag': 'CashOperGener',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485754',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485755,
#   'sec_filing_id': 1202255,
#   'effective_value': 4800000000.0,
#   'reported_value': 4800000000.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD',
#   'qname_id_min': 0,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': 7,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'cash from operations',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 2,
#   'extract_tag': 'CashOper',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485755',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485756,
#   'sec_filing_id': 1202255,
#   'effective_value': 711000000.0,
#   'reported_value': 711000000.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD',
#   'qname_id_min': 0,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': 8,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'shareholders through share - returned',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 1,
#   'extract_tag': 'ShareholdThroughShareReturn',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485756',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485757,
#   'sec_filing_id': 1202255,
#   'effective_value': 0.5,
#   'reported_value': 0.5,
#   'entity_id': 675,
#   'fiscal_year': 2018,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD/shares',
#   'qname_id_min': 0,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': 9,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'cash dividend per share - declared',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 1,
#   'extract_tag': 'CashDividendPerShareDeclar',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': True,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485757',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485758,
#   'sec_filing_id': 1202255,
#   'effective_value': 0.3,
#   'reported_value': 30.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Y',
#   'UOM': 'PCT',
#   'qname_id_min': 0,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': 10,
#   'statement_type': 'TEXT',
#   'table_id': 'TEXT',
#   'label': 'reflected strength in capacity enterprise, surveillance hard drives and embedded flash solutions, with each growing revenue',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 1,
#   'extract_tag': 'ReflectStrengthCapacEnterprisSurveilHardDriveEmbedFlashSolutEachGrowRevenu_PCT',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': True,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485758',
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485765,
#   'sec_filing_id': 1202255,
#   'effective_value': None,
#   'reported_value': None,
#   'entity_id': 675,
#   'fiscal_year': None,
#   'fiscal_period': None,
#   'UOM': '',
#   'qname_id_min': 0,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': -3,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'WESTERN DIGITAL CORPORATION',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 1,
#   'extract_tag': '',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': None,
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485766,
#   'sec_filing_id': 1202255,
#   'effective_value': None,
#   'reported_value': None,
#   'entity_id': 675,
#   'fiscal_year': None,
#   'fiscal_period': None,
#   'UOM': '',
#   'qname_id_min': 0,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': -2,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'PRELIMINARY CONDENSED CONSOLIDATED BALANCE SHEETS',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 1,
#   'extract_tag': '',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': None,
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485767,
#   'sec_filing_id': 1202255,
#   'effective_value': None,
#   'reported_value': None,
#   'entity_id': 675,
#   'fiscal_year': None,
#   'fiscal_period': None,
#   'UOM': '',
#   'qname_id_min': 0,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': -1,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': '(in millions; unaudited; on a US GAAP basis)',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 0,
#   'column_index': 1,
#   'extract_tag': '',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': None,
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485768,
#   'sec_filing_id': 1202255,
#   'effective_value': None,
#   'reported_value': None,
#   'entity_id': 675,
#   'fiscal_year': None,
#   'fiscal_period': None,
#   'UOM': '',
#   'qname_id_min': 0,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': 1,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'ASSETS',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 3,
#   'column_index': 1,
#   'extract_tag': '',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': None,
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485769,
#   'sec_filing_id': 1202255,
#   'effective_value': None,
#   'reported_value': None,
#   'entity_id': 675,
#   'fiscal_year': None,
#   'fiscal_period': None,
#   'UOM': '',
#   'qname_id_min': 0,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': 2,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Current assets:',
#   'indent_level': 1,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 4,
#   'column_index': 1,
#   'extract_tag': '',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': None,
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485550,
#   'sec_filing_id': 1202255,
#   'effective_value': 4646000000.0,
#   'reported_value': 4646.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD',
#   'qname_id_min': 4745,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-09-28T00:00:00',
#   'presentation_order': 3,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Cash and cash equivalents',
#   'indent_level': 2,
#   'column_label': 'Sept. 28, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 5,
#   'column_index': 4,
#   'extract_tag': 'CashCashEquival',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485550',
#   'matching_extract_tag': 'CashCashEquival',
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': 281485850,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485850'},
#  {'fact_id': 281485551,
#   'sec_filing_id': 1202255,
#   'effective_value': 5005000000.0,
#   'reported_value': 5005.0,
#   'entity_id': 675,
#   'fiscal_year': 2018,
#   'fiscal_period': 'Y',
#   'UOM': 'USD',
#   'qname_id_min': 4745,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-06-29T00:00:00',
#   'presentation_order': 3,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Cash and cash equivalents',
#   'indent_level': 2,
#   'column_label': 'June 29, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 5,
#   'column_index': 8,
#   'extract_tag': 'CashCashEquival',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485551',
#   'matching_extract_tag': 'CashCashEquival',
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': 281485850,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485850'},
#  {'fact_id': 281485552,
#   'sec_filing_id': 1202255,
#   'effective_value': 2219000000.0,
#   'reported_value': 2219.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': '',
#   'qname_id_min': 9728,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-09-28T00:00:00',
#   'presentation_order': 4,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Accounts receivable, net',
#   'indent_level': 2,
#   'column_label': 'Sept. 28, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 6,
#   'column_index': 4,
#   'extract_tag': 'AccountReceivNet',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485552',
#   'matching_extract_tag': 'AccountReceivNet',
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': 281485852,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485852'},
#  {'fact_id': 281485553,
#   'sec_filing_id': 1202255,
#   'effective_value': 2197000000.0,
#   'reported_value': 2197.0,
#   'entity_id': 675,
#   'fiscal_year': 2018,
#   'fiscal_period': 'Y',
#   'UOM': '',
#   'qname_id_min': 9728,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-06-29T00:00:00',
#   'presentation_order': 4,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Accounts receivable, net',
#   'indent_level': 2,
#   'column_label': 'June 29, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 6,
#   'column_index': 8,
#   'extract_tag': 'AccountReceivNet',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485553',
#   'matching_extract_tag': 'AccountReceivNet',
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': 281485852,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485852'},
#  {'fact_id': 281485554,
#   'sec_filing_id': 1202255,
#   'effective_value': 3119000000.0,
#   'reported_value': 3119.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': '',
#   'qname_id_min': 11612,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-09-28T00:00:00',
#   'presentation_order': 5,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Inventories',
#   'indent_level': 2,
#   'column_label': 'Sept. 28, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 7,
#   'column_index': 4,
#   'extract_tag': 'Inventori',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485554',
#   'matching_extract_tag': 'Inventori',
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': 281485854,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485854'},
#  {'fact_id': 281485555,
#   'sec_filing_id': 1202255,
#   'effective_value': 2944000000.0,
#   'reported_value': 2944.0,
#   'entity_id': 675,
#   'fiscal_year': 2018,
#   'fiscal_period': 'Y',
#   'UOM': '',
#   'qname_id_min': 11612,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-06-29T00:00:00',
#   'presentation_order': 5,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Inventories',
#   'indent_level': 2,
#   'column_label': 'June 29, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 7,
#   'column_index': 8,
#   'extract_tag': 'Inventori',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485555',
#   'matching_extract_tag': 'Inventori',
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': 281485854,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485854'},
#  {'fact_id': 281485556,
#   'sec_filing_id': 1202255,
#   'effective_value': 587000000.0,
#   'reported_value': 587.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': '',
#   'qname_id_min': 10614,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-09-28T00:00:00',
#   'presentation_order': 6,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Other current assets',
#   'indent_level': 2,
#   'column_label': 'Sept. 28, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 8,
#   'column_index': 4,
#   'extract_tag': 'OtherCurrentAsset',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485556',
#   'matching_extract_tag': 'OtherCurrentAsset',
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': 281485856,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485856'},
#  {'fact_id': 281485557,
#   'sec_filing_id': 1202255,
#   'effective_value': 492000000.0,
#   'reported_value': 492.0,
#   'entity_id': 675,
#   'fiscal_year': 2018,
#   'fiscal_period': 'Y',
#   'UOM': '',
#   'qname_id_min': 10614,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-06-29T00:00:00',
#   'presentation_order': 6,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Other current assets',
#   'indent_level': 2,
#   'column_label': 'June 29, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 8,
#   'column_index': 8,
#   'extract_tag': 'OtherCurrentAsset',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485557',
#   'matching_extract_tag': 'OtherCurrentAsset',
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': 281485856,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485856'},
#  {'fact_id': 281485558,
#   'sec_filing_id': 1202255,
#   'effective_value': 10571000000.0,
#   'reported_value': 10571.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': '',
#   'qname_id_min': 8123,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-09-28T00:00:00',
#   'presentation_order': 7,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Total current assets',
#   'indent_level': 3,
#   'column_label': 'Sept. 28, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 10,
#   'column_index': 4,
#   'extract_tag': 'CurrentAsset',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485558',
#   'matching_extract_tag': 'CurrentAsset',
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': 281485858,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485858'},
#  {'fact_id': 281485559,
#   'sec_filing_id': 1202255,
#   'effective_value': 10638000000.0,
#   'reported_value': 10638.0,
#   'entity_id': 675,
#   'fiscal_year': 2018,
#   'fiscal_period': 'Y',
#   'UOM': '',
#   'qname_id_min': 8123,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-06-29T00:00:00',
#   'presentation_order': 7,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Total current assets',
#   'indent_level': 3,
#   'column_label': 'June 29, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 10,
#   'column_index': 8,
#   'extract_tag': 'CurrentAsset',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485559',
#   'matching_extract_tag': 'CurrentAsset',
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': 281485858,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485858'},
#  {'fact_id': 281485560,
#   'sec_filing_id': 1202255,
#   'effective_value': 3054000000.0,
#   'reported_value': 3054.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': '',
#   'qname_id_min': 18378,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-09-28T00:00:00',
#   'presentation_order': 8,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Property, plant and equipment, net',
#   'indent_level': 1,
#   'column_label': 'Sept. 28, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 11,
#   'column_index': 4,
#   'extract_tag': 'PropertiPlantEquipNet',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485560',
#   'matching_extract_tag': 'PropertiPlantEquipNet',
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': 281485860,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485860'},
#  {'fact_id': 281485561,
#   'sec_filing_id': 1202255,
#   'effective_value': 3095000000.0,
#   'reported_value': 3095.0,
#   'entity_id': 675,
#   'fiscal_year': 2018,
#   'fiscal_period': 'Y',
#   'UOM': '',
#   'qname_id_min': 18378,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-06-29T00:00:00',
#   'presentation_order': 8,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Property, plant and equipment, net',
#   'indent_level': 1,
#   'column_label': 'June 29, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 11,
#   'column_index': 8,
#   'extract_tag': 'PropertiPlantEquipNet',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485561',
#   'matching_extract_tag': 'PropertiPlantEquipNet',
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': 281485860,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485860'},
#  {'fact_id': 281485562,
#   'sec_filing_id': 1202255,
#   'effective_value': 2028000000.0,
#   'reported_value': 2028.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': '',
#   'qname_id_min': 32760,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-09-28T00:00:00',
#   'presentation_order': 9,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Notes receivable and investments in Flash Ventures',
#   'indent_level': 1,
#   'column_label': 'Sept. 28, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 12,
#   'column_index': 4,
#   'extract_tag': 'NoteReceivInvestFlashVentur',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485562',
#   'matching_extract_tag': 'NoteReceivInvestFlashVentur',
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': 281485862,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485862'},
#  {'fact_id': 281485563,
#   'sec_filing_id': 1202255,
#   'effective_value': 2105000000.0,
#   'reported_value': 2105.0,
#   'entity_id': 675,
#   'fiscal_year': 2018,
#   'fiscal_period': 'Y',
#   'UOM': '',
#   'qname_id_min': 32760,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-06-29T00:00:00',
#   'presentation_order': 9,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Notes receivable and investments in Flash Ventures',
#   'indent_level': 1,
#   'column_label': 'June 29, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 12,
#   'column_index': 8,
#   'extract_tag': 'NoteReceivInvestFlashVentur',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485563',
#   'matching_extract_tag': 'NoteReceivInvestFlashVentur',
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': 281485862,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485862'},
#  {'fact_id': 281485564,
#   'sec_filing_id': 1202255,
#   'effective_value': 10072000000.0,
#   'reported_value': 10072.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': '',
#   'qname_id_min': 6884,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-09-28T00:00:00',
#   'presentation_order': 10,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Goodwill',
#   'indent_level': 1,
#   'column_label': 'Sept. 28, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 13,
#   'column_index': 4,
#   'extract_tag': 'Goodwil',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485564',
#   'matching_extract_tag': 'Goodwil',
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': 281485864,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485864'},
#  {'fact_id': 281485565,
#   'sec_filing_id': 1202255,
#   'effective_value': 10075000000.0,
#   'reported_value': 10075.0,
#   'entity_id': 675,
#   'fiscal_year': 2018,
#   'fiscal_period': 'Y',
#   'UOM': '',
#   'qname_id_min': 6884,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-06-29T00:00:00',
#   'presentation_order': 10,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Goodwill',
#   'indent_level': 1,
#   'column_label': 'June 29, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 13,
#   'column_index': 8,
#   'extract_tag': 'Goodwil',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485565',
#   'matching_extract_tag': 'Goodwil',
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': 281485864,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485864'},
#  {'fact_id': 281485566,
#   'sec_filing_id': 1202255,
#   'effective_value': 2404000000.0,
#   'reported_value': 2404.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': '',
#   'qname_id_min': 14018,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-09-28T00:00:00',
#   'presentation_order': 11,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Other intangible assets, net',
#   'indent_level': 1,
#   'column_label': 'Sept. 28, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 14,
#   'column_index': 4,
#   'extract_tag': 'OtherIntangAssetNet',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485566',
#   'matching_extract_tag': 'OtherIntangAssetNet',
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': 281485866,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485866'},
#  {'fact_id': 281485567,
#   'sec_filing_id': 1202255,
#   'effective_value': 2680000000.0,
#   'reported_value': 2680.0,
#   'entity_id': 675,
#   'fiscal_year': 2018,
#   'fiscal_period': 'Y',
#   'UOM': '',
#   'qname_id_min': 14018,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': '2018-06-29T00:00:00',
#   'presentation_order': 11,
#   'statement_type': '2',
#   'table_id': '0',
#   'label': 'Other intangible assets, net',
#   'indent_level': 1,
#   'column_label': 'June 29, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 14,
#   'column_index': 8,
#   'extract_tag': 'OtherIntangAssetNet',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': 'PreliminariCondensConsolidBalancSheet',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485567',
#   'matching_extract_tag': 'OtherIntangAssetNet',
# ...
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485728',
#   'matching_extract_tag': 'GaapNetIncomIncomTaxAdjust',
#   'matching_fact_id_q': 281486210,
#   'matching_fact_id_cumulative': 281486212,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281486210'},
#  {'fact_id': 281485729,
#   'sec_filing_id': 1202255,
#   'effective_value': -55000000.0,
#   'reported_value': -55.0,
#   'entity_id': 675,
#   'fiscal_year': 2018,
#   'fiscal_period': 'Q1',
#   'UOM': '',
#   'qname_id_min': 4150985,
#   'period_start': '2017-06-29T00:00:00',
#   'period_end': '2017-09-29T00:00:00',
#   'period_instant': None,
#   'presentation_order': 9,
#   'statement_type': '271',
#   'table_id': '4',
#   'label': 'Income tax adjustments',
#   'indent_level': 1,
#   'column_label': 'Three Months Ended Sept. 29, 2017',
#   'column_label_short': '',
#   'presentation_order_original': 12,
#   'column_index': 8,
#   'extract_tag': 'GaapNetIncomIncomTaxAdjust',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485729',
#   'matching_extract_tag': 'GaapNetIncomIncomTaxAdjust',
#   'matching_fact_id_q': 281486210,
#   'matching_fact_id_cumulative': 281486212,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281486210'},
#  {'fact_id': 281485730,
#   'sec_filing_id': 1202255,
#   'effective_value': 906000000.0,
#   'reported_value': 906.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD',
#   'qname_id_min': 4150986,
#   'period_start': '2018-06-28T00:00:00',
#   'period_end': '2018-09-28T00:00:00',
#   'period_instant': None,
#   'presentation_order': 10,
#   'statement_type': '271',
#   'table_id': '4',
#   'label': 'Non-GAAP net income',
#   'indent_level': 0,
#   'column_label': 'Three Months Ended Sept. 28, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 14,
#   'column_index': 4,
#   'extract_tag': 'NongaapNetIncom',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': True,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485730',
#   'matching_extract_tag': 'NongaapNetIncom',
#   'matching_fact_id_q': 281486214,
#   'matching_fact_id_cumulative': 281486216,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281486214'},
#  {'fact_id': 281485731,
#   'sec_filing_id': 1202255,
#   'effective_value': 1089000000.0,
#   'reported_value': 1089.0,
#   'entity_id': 675,
#   'fiscal_year': 2018,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD',
#   'qname_id_min': 4150986,
#   'period_start': '2017-06-29T00:00:00',
#   'period_end': '2017-09-29T00:00:00',
#   'period_instant': None,
#   'presentation_order': 10,
#   'statement_type': '271',
#   'table_id': '4',
#   'label': 'Non-GAAP net income',
#   'indent_level': 0,
#   'column_label': 'Three Months Ended Sept. 29, 2017',
#   'column_label_short': '',
#   'presentation_order_original': 14,
#   'column_index': 8,
#   'extract_tag': 'NongaapNetIncom',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': True,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485731',
#   'matching_extract_tag': 'NongaapNetIncom',
#   'matching_fact_id_q': 281486214,
#   'matching_fact_id_cumulative': 281486216,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281486214'},
#  {'fact_id': 281485783,
#   'sec_filing_id': 1202255,
#   'effective_value': None,
#   'reported_value': None,
#   'entity_id': 675,
#   'fiscal_year': None,
#   'fiscal_period': None,
#   'UOM': '',
#   'qname_id_min': 0,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': 11,
#   'statement_type': '271',
#   'table_id': '4',
#   'label': 'Diluted income per common share:',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 16,
#   'column_index': 1,
#   'extract_tag': '',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': None,
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485732,
#   'sec_filing_id': 1202255,
#   'effective_value': 1.71,
#   'reported_value': 1.71,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD/shares',
#   'qname_id_min': 3023504,
#   'period_start': '2018-06-28T00:00:00',
#   'period_end': '2018-09-28T00:00:00',
#   'period_instant': None,
#   'presentation_order': 12,
#   'statement_type': '271',
#   'table_id': '4',
#   'label': 'GAAP',
#   'indent_level': 1,
#   'column_label': 'Three Months Ended Sept. 28, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 17,
#   'column_index': 4,
#   'extract_tag': 'DilutIncomPerCommonShareGaap',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485732',
#   'matching_extract_tag': 'DilutIncomPerCommonShareGaap',
#   'matching_fact_id_q': 281486218,
#   'matching_fact_id_cumulative': 281486220,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281486218'},
#  {'fact_id': 281485733,
#   'sec_filing_id': 1202255,
#   'effective_value': 2.23,
#   'reported_value': 2.23,
#   'entity_id': 675,
#   'fiscal_year': 2018,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD/shares',
#   'qname_id_min': 3023504,
#   'period_start': '2017-06-29T00:00:00',
#   'period_end': '2017-09-29T00:00:00',
#   'period_instant': None,
#   'presentation_order': 12,
#   'statement_type': '271',
#   'table_id': '4',
#   'label': 'GAAP',
#   'indent_level': 1,
#   'column_label': 'Three Months Ended Sept. 29, 2017',
#   'column_label_short': '',
#   'presentation_order_original': 17,
#   'column_index': 8,
#   'extract_tag': 'DilutIncomPerCommonShareGaap',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485733',
#   'matching_extract_tag': 'DilutIncomPerCommonShareGaap',
#   'matching_fact_id_q': 281486218,
#   'matching_fact_id_cumulative': 281486220,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281486218'},
#  {'fact_id': 281485734,
#   'sec_filing_id': 1202255,
#   'effective_value': 3.04,
#   'reported_value': 3.04,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD/shares',
#   'qname_id_min': 4150986,
#   'period_start': '2018-06-28T00:00:00',
#   'period_end': '2018-09-28T00:00:00',
#   'period_instant': None,
#   'presentation_order': 13,
#   'statement_type': '271',
#   'table_id': '4',
#   'label': 'Non-GAAP',
#   'indent_level': 1,
#   'column_label': 'Three Months Ended Sept. 28, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 19,
#   'column_index': 4,
#   'extract_tag': 'DilutIncomPerCommonShareNongaap',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': True,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485734',
#   'matching_extract_tag': 'DilutIncomPerCommonShareNongaap',
#   'matching_fact_id_q': 281486222,
#   'matching_fact_id_cumulative': 281486224,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281486222'},
#  {'fact_id': 281485735,
#   'sec_filing_id': 1202255,
#   'effective_value': 3.56,
#   'reported_value': 3.56,
#   'entity_id': 675,
#   'fiscal_year': 2018,
#   'fiscal_period': 'Q1',
#   'UOM': 'USD/shares',
#   'qname_id_min': 4150986,
#   'period_start': '2017-06-29T00:00:00',
#   'period_end': '2017-09-29T00:00:00',
#   'period_instant': None,
#   'presentation_order': 13,
#   'statement_type': '271',
#   'table_id': '4',
#   'label': 'Non-GAAP',
#   'indent_level': 1,
#   'column_label': 'Three Months Ended Sept. 29, 2017',
#   'column_label_short': '',
#   'presentation_order_original': 19,
#   'column_index': 8,
#   'extract_tag': 'DilutIncomPerCommonShareNongaap',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': True,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485735',
#   'matching_extract_tag': 'DilutIncomPerCommonShareNongaap',
#   'matching_fact_id_q': 281486222,
#   'matching_fact_id_cumulative': 281486224,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281486222'},
#  {'fact_id': 281485784,
#   'sec_filing_id': 1202255,
#   'effective_value': None,
#   'reported_value': None,
#   'entity_id': 675,
#   'fiscal_year': None,
#   'fiscal_period': None,
#   'UOM': '',
#   'qname_id_min': 0,
#   'period_start': None,
#   'period_end': None,
#   'period_instant': None,
#   'presentation_order': 14,
#   'statement_type': '271',
#   'table_id': '4',
#   'label': 'Diluted weighted average shares outstanding:',
#   'indent_level': 0,
#   'column_label': '',
#   'column_label_short': '',
#   'presentation_order_original': 21,
#   'column_index': 1,
#   'extract_tag': '',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': None,
#   'matching_extract_tag': None,
#   'matching_fact_id_q': None,
#   'matching_fact_id_cumulative': None,
#   'exact_match': None,
#   'matching_trace_link': None},
#  {'fact_id': 281485736,
#   'sec_filing_id': 1202255,
#   'effective_value': 298000000.0,
#   'reported_value': 298.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'shares',
#   'qname_id_min': 3023504,
#   'period_start': '2018-06-28T00:00:00',
#   'period_end': '2018-09-28T00:00:00',
#   'period_instant': None,
#   'presentation_order': 15,
#   'statement_type': '271',
#   'table_id': '4',
#   'label': 'GAAP',
#   'indent_level': 1,
#   'column_label': 'Three Months Ended Sept. 28, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 22,
#   'column_index': 4,
#   'extract_tag': 'DilutWeightAveragShareOutstandGaap',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485736',
#   'matching_extract_tag': 'DilutWeightAveragShareOutstandGaap',
#   'matching_fact_id_q': 281486226,
#   'matching_fact_id_cumulative': 281486228,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281486226'},
#  {'fact_id': 281485737,
#   'sec_filing_id': 1202255,
#   'effective_value': 306000000.0,
#   'reported_value': 306.0,
#   'entity_id': 675,
#   'fiscal_year': 2018,
#   'fiscal_period': 'Q1',
#   'UOM': 'shares',
#   'qname_id_min': 3023504,
#   'period_start': '2017-06-29T00:00:00',
#   'period_end': '2017-09-29T00:00:00',
#   'period_instant': None,
#   'presentation_order': 15,
#   'statement_type': '271',
#   'table_id': '4',
#   'label': 'GAAP',
#   'indent_level': 1,
#   'column_label': 'Three Months Ended Sept. 29, 2017',
#   'column_label_short': '',
#   'presentation_order_original': 22,
#   'column_index': 8,
#   'extract_tag': 'DilutWeightAveragShareOutstandGaap',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': False,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485737',
#   'matching_extract_tag': 'DilutWeightAveragShareOutstandGaap',
#   'matching_fact_id_q': 281486226,
#   'matching_fact_id_cumulative': 281486228,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281486226'},
#  {'fact_id': 281485738,
#   'sec_filing_id': 1202255,
#   'effective_value': 298000000.0,
#   'reported_value': 298.0,
#   'entity_id': 675,
#   'fiscal_year': 2019,
#   'fiscal_period': 'Q1',
#   'UOM': 'shares',
#   'qname_id_min': 4150986,
#   'period_start': '2018-06-28T00:00:00',
#   'period_end': '2018-09-28T00:00:00',
#   'period_instant': None,
#   'presentation_order': 16,
#   'statement_type': '271',
#   'table_id': '4',
#   'label': 'Non-GAAP',
#   'indent_level': 1,
#   'column_label': 'Three Months Ended Sept. 28, 2018',
#   'column_label_short': '',
#   'presentation_order_original': 24,
#   'column_index': 4,
#   'extract_tag': 'DilutWeightAveragShareOutstandNongaap',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': True,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485738',
#   'matching_extract_tag': 'DilutWeightAveragShareOutstandNongaap',
#   'matching_fact_id_q': 281486230,
#   'matching_fact_id_cumulative': 281486232,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281486230'},
#  {'fact_id': 281485739,
#   'sec_filing_id': 1202255,
#   'effective_value': 306000000.0,
#   'reported_value': 306.0,
#   'entity_id': 675,
#   'fiscal_year': 2018,
#   'fiscal_period': 'Q1',
#   'UOM': 'shares',
#   'qname_id_min': 4150986,
#   'period_start': '2017-06-29T00:00:00',
#   'period_end': '2017-09-29T00:00:00',
#   'period_instant': None,
#   'presentation_order': 16,
#   'statement_type': '271',
#   'table_id': '4',
#   'label': 'Non-GAAP',
#   'indent_level': 1,
#   'column_label': 'Three Months Ended Sept. 29, 2017',
#   'column_label_short': '',
#   'presentation_order_original': 24,
#   'column_index': 8,
#   'extract_tag': 'DilutWeightAveragShareOutstandNongaap',
#   'range_low': False,
#   'range_high': False,
#   'is_guidance': False,
#   'is_ulp_metric': False,
#   'is_strict': False,
#   'filing_section': None,
#   'is_non_gaap': True,
#   'is_change_amount': False,
#   'is_segment': False,
#   'is_bop_value': None,
#   'table_tag': '',
#   'trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281485739',
#   'matching_extract_tag': 'DilutWeightAveragShareOutstandNongaap',
#   'matching_fact_id_q': 281486230,
#   'matching_fact_id_cumulative': 281486232,
#   'exact_match': True,
#   'matching_trace_link': 'https://www.calcbench.com/traceFactNonXBRL/281486230'}]
