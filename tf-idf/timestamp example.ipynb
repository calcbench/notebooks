# %%
from cb_tf_idf import timestamp_diffs
import calcbench as cb

# %%
tickers = cb.tickers(index='DJIA')

# %%
timestamp_diffs("Management's Discussion And Analysis", tickers)
# Out:
# ...
#                                 distance  word_count
# ticker timestamp
# MMM    2009-07-31 16:21:10.000       NaN        7395
#        2009-10-30 15:12:41.000  0.005928        7005
#        2010-02-16 15:07:30.000  0.015139       12841
#        2010-05-05 16:12:10.000  0.015990        5335
#        2010-08-04 16:54:03.000  0.008758        6675
#        2010-11-05 14:05:57.000  0.007370        7309
#        2011-02-16 17:18:34.000  0.020671       10799
#        2011-05-05 13:56:27.000  0.017156        5732
#        2011-08-04 16:39:00.000  0.009157        7428
#        2011-11-03 15:42:31.000  0.007484        7684
#        2012-02-16 15:42:31.000  0.014702       11620
#        2012-05-03 12:03:37.000  0.014113        5635
#        2012-08-02 16:15:12.000  0.015355        7469
#        2012-11-01 15:38:55.000  0.005325        7629
#        2013-02-14 16:28:05.000  0.015944       11040
#        2013-05-02 15:57:56.000  0.014939        5703
# ...

# %%
risk_factor_diffs = _

# %%
risk_factor_diffs.to_excel(r"C:\Users\Andrew Kittredge\Dropbox (Calcbench)\Clients\PDT Partners\Data\md_a_factor_distances.xlsx")
