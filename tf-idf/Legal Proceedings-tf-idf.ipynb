# %%
import calcbench as cb
from sklearn.feature_extraction.text import TfidfVectorizer
from bs4 import BeautifulSoup
from scipy.spatial.distance import cosine
from IPython.core.display import display, HTML
import sklearn
import itertools
from tqdm import tqdm_notebook
from matplotlib import colors
import matplotlib.pyplot as plt

# %%
class NumberNormalizingVectorizer(sklearn.feature_extraction.text.TfidfVectorizer):
    def build_tokenizer(self):
        tokenize = super(NumberNormalizingVectorizer, self).build_tokenizer()
        return lambda doc: list(number_normalizer(tokenize(doc)))

# %%
def number_normalizer(tokens):
    """ Map all numeric tokens to a placeholder.

    For many applications, tokens that begin with a number are not directly
    useful, but the fact that such a token exists can be relevant.  By applying
    this form of dimensionality reduction, some methods may perform better.
    """

    return ("#NUMBER" if token[0].isdigit() else token for token in tokens)

# %%
def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = itertools.tee(iterable)
    next(b, None)
    return zip(a, b)

# %%
tickers = """ABCB
ABTX
ACBI
AGM
AMTD
ANCX
AROW
ASB
ATAX
BAC
BANC
BANF
BANR
BBT
BCBP
BCML
BDGE
BFIN
BFST
BGCP
BHB
BHBK
BHLB
BKU
BMRC
BMTC
BNCL
BOCH
BOFI
BOH
BPFH
BPRN
BRKL
BSRR
BUSE
BWB
BXS
BY
C
CAC
CADE
CARO
CASH
CATC
CATY
CBSH
CBTX
CBU
CCBG
CCNE
CFFI
CFG
CFR
CHCO
CHFC
CIT
CIVB
CLBK
CMA
CNBKA
CNOB
COBZ
COLB
COWN
CPF
CSFL
CSTR
CTBI
CUBI
CVBF
CVCY
CZNC
DCOM
EBSB
EFSC
EGBN
EQBK
EQH
ESQ
ETFC
EVR
EWBC
FBC
FBIZ
FBK
FBMS
FBNC
FBNK
FCB
FCBC
FCF
FCNCA
FDEF
FFBC
FFIC
FFIN
FFNW
FFWM
FHB
FHN
FIBK
FISI
FITB
FLIC
FMAO
FMBH
FMBI
FMNB
FNB
FNLC
FRBK
FRC
FRME
FSB
FSBW
FULT
GABC
GBCI
GBNK
GCAP
GHL
GNBC
GNTY
GS
GSBC
GWB
HAFC
HBAN
HBCP
HBMD
HBNC
HFWA
HIFS
HLI
HMST
HOMB
HONE
HOPE
HTBI
HTBK
HTH
HTLF
HWC
IBCP
IBKC
IBKR
IBOC
IBTX
INBK
INDB
INTL
ISBC
ITG
JPM
KEY
KRNY
LBAI
LBC
LEVL
LION
LKFN
LOB
LPLA
LTS
LTXB
MBFI
MBIN
MBTF
MBWM
MC
MCB
MCBC
MOFG
MS
MSBI
MSL
MTB
MTG
NBHC
NBN
NBTB
NCBS
NCOM
NFBK
NMIH
NRIM
NWBI
NYCB
OBNK
OCFC
OCN
OLBK
ONB
OPB
OPY
ORIT
OSBC
OZK
PACW
PB
PBCT
PCSB
PEBO
PFBC
PFS
PFSI
PGC
PHH
PJC
PJT
PNC
PNFP
PPBI
PRK
PUB
PWOD
QCRH
RBB
RBCAA
RDN
RF
RILY
RJF
RNST
RVSB
SASR
SBBX
SBCF
SBNY
SBSI
SBT
SCHW
SF
SFBS
SFNC
SFST
SHBI
SIEB
SIVB
SMBC
SMBK
SMMF
SNFCA
SNV
SONA
SRCE
SSB
STBA
STBZ
STI
STL
STXB
SYBT
TBBK
TBK
TBNK
TCBI
TCBK
TCF
THFF
TMP
TOWN
TREE
TRMK
TRST
TSBK
TSC
UBNK
UBSH
UBSI
UCBI
UCFC
UMBF
UMPQ
USB
UVSP
VBTX
VIRT
VLY
VOYA
WABC
WAFD
WAL
WASH
WBS
WD
WFC
WNEB
WSBC
WSBF
WSFS
WTBA
WTFC
ZION
""".splitlines()

# %%
document_section = "Legal Proceedings"
first_year = 2008
end_year = 2018
diffs = pd.DataFrame(index=tickers, columns=range(end_year, first_year, -1))
for ticker in tqdm_notebook(tickers):
    ten_K_sections = (d for d in cb.document_search(company_identifiers=[ticker], 
                                                document_name=document_section, 
                                                all_history=True) if d['fiscal_period'] == 'Y')
    sorted_disclosures = sorted(ten_K_sections, key=lambda d: d['fiscal_year'])
    year_pairs = pairwise(sorted_disclosures)
    for last_year, this_year in year_pairs:
        text_last_year = BeautifulSoup(last_year.get_contents(), 'html.parser').text
        text_this_year = BeautifulSoup(this_year.get_contents(), 'html.parser').text
        vectorizer = NumberNormalizingVectorizer(stop_words='english')
        X = vectorizer.fit_transform([text_this_year, text_last_year])
        distance = cosine(X[0].todense(), X[1].todense())
        diffs[this_year['fiscal_year']][ticker] = distance
# Out:
# HBox(children=(IntProgress(value=0, max=294), HTML(value='')))
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-10-7344fd539d05> in <module>
#      11     for last_year, this_year in year_pairs:
#      12         text_last_year = BeautifulSoup(last_year.get_contents(), 'html.parser').text
# ---> 13         text_this_year = BeautifulSoup(this_year.get_contents(), 'html.parser').text
#      14         vectorizer = NumberNormalizingVectorizer(stop_words='english')
#      15         X = vectorizer.fit_transform([text_this_year, text_last_year])
#
# ~\git\python_api_client\calcbench\api_client.py in get_contents(self)
#     582             return document_contents_by_network_id(self['network_id'])
#     583         else:
# --> 584             return document_contents(blob_id=self['blob_id'], SEC_ID=self['sec_filing_id'])
#     585
#     586 def document_contents(blob_id, SEC_ID, SEC_URL=None):
#
# ~\git\python_api_client\calcbench\api_client.py in document_contents(blob_id, SEC_ID, SEC_URL)
#     592                                         verify=_SESSION_STUFF['ssl_verify'],
#     593                                         timeout=_SESSION_STUFF['timeout'])
# --> 594     response.raise_for_status()
#     595     return response.json()['blobs'][0]
#     596
#
# c:\users\andrew kittredge\appdata\local\programs\python\python37-32\lib\site-packages\requests\models.py in raise_for_status(self)
#     938
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#     942     def close(self):
#
# HTTPError: 404 Client Error: Missing blob text for 216615 for url: https://www.calcbench.com/query/disclosureBySECLink?blobid=216615_section130&secid=216615

# %%
def background_gradient(s, m, M, cmap='PuBu', low=0, high=0):
    # from https://stackoverflow.com/questions/38931566/pandas-style-background-gradient-both-rows-and-columns
    rng = M - m
    norm = colors.Normalize(m - (rng * low),
                            M + (rng * high))
    normed = norm(s.values)
    c = [colors.rgb2hex(x) for x in plt.cm.get_cmap(cmap)(normed)]
    return ['background-color: %s' % color for color in c]

def highlight_largest_diffs(diffs):
    filled_df = diffs.loc[diffs.sum(axis=1).sort_values(ascending=False).index].fillna(0).round(3)
    return filled_df.style.apply(background_gradient, cmap='Reds', m=filled_df.min().min(), M=filled_df.max().max(), low=0, high=2.5)

# %% [markdown]
# ## Hightlight Risk Factors with Greatest Change
# ### Brightest cells are those documents which changed the most vis-a-vis the previous period.

# %%
highlight_largest_diffs(diffs)
# Out:
# <style  type="text/css" >
#     #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow0_col0 {
#             background-color:  #fee4d8;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow0_col1 {
#             background-color:  #fdd1be;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow0_col2 {
#             background-color:  #fee8dd;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow0_col3 {
#             background-color:  #fedaca;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow0_col4 {
#             background-color:  #fee5d8;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow0_col5 {
#             background-color:  #fee3d7;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow0_col6 {
#             background-color:  #fedaca;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow0_col7 {
#             background-color:  #fedccd;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow0_col8 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow0_col9 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow1_col0 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow1_col1 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow1_col2 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow1_col3 {
#             background-color:  #fcaf93;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow1_col4 {
#             background-color:  #fee6da;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow1_col5 {
#             background-color:  #fedecf;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow1_col6 {
#             background-color:  #fdc6b0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow1_col7 {
#             background-color:  #fee3d7;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow1_col8 {
#             background-color:  #ffefe8;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow1_col9 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow2_col0 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow2_col1 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow2_col2 {
#             background-color:  #fdd2bf;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow2_col3 {
#             background-color:  #fdd2bf;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow2_col4 {
#             background-color:  #feeae0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow2_col5 {
#             background-color:  #fdd2bf;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow2_col6 {
#             background-color:  #fdd7c6;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow2_col7 {
#             background-color:  #fff2ec;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow2_col8 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow2_col9 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow3_col0 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow3_col1 {
#             background-color:  #fee3d6;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow3_col2 {
#             background-color:  #ffede5;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow3_col3 {
#             background-color:  #ffece4;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow3_col4 {
#             background-color:  #ffebe2;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow3_col5 {
#             background-color:  #fdc6b0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow3_col6 {
#             background-color:  #fee0d2;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow3_col7 {
#             background-color:  #ffefe8;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow3_col8 {
#             background-color:  #feeae1;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow3_col9 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow4_col0 {
#             background-color:  #feeae1;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow4_col1 {
#             background-color:  #fedfd0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow4_col2 {
#             background-color:  #fee6da;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow4_col3 {
#             background-color:  #fff2eb;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow4_col4 {
#             background-color:  #fff2eb;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow4_col5 {
#             background-color:  #ffeee7;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow4_col6 {
#             background-color:  #fee1d3;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow4_col7 {
#             background-color:  #fff2eb;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow4_col8 {
#             background-color:  #fee2d5;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow4_col9 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow5_col0 {
#             background-color:  #fff4ef;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow5_col1 {
#             background-color:  #fee8de;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow5_col2 {
#             background-color:  #ffece4;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow5_col3 {
#             background-color:  #fdd7c6;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow5_col4 {
#             background-color:  #ffebe2;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow5_col5 {
#             background-color:  #ffeee7;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow5_col6 {
#             background-color:  #fee7dc;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow5_col7 {
#             background-color:  #fff0e8;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow5_col8 {
#             background-color:  #fee7dc;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow5_col9 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow6_col0 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow6_col1 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow6_col2 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow6_col3 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow6_col4 {
#             background-color:  #fee4d8;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow6_col5 {
#             background-color:  #feeae1;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow6_col6 {
#             background-color:  #fff4ee;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow6_col7 {
#             background-color:  #fdd2bf;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow6_col8 {
#             background-color:  #fdcdb9;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow6_col9 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow7_col0 {
#             background-color:  #fff5f0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow7_col1 {
#             background-color:  #ffece4;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow7_col2 {
#             background-color:  #fedfd0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow7_col3 {
#             background-color:  #ffefe8;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow7_col4 {
#             background-color:  #fedfd0;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow7_col5 {
#             background-color:  #fee9df;
#         }    #T_45cb49e6_3c5a_11e9_b8ec_0c54a51d1a3crow7_col6 {
#             bac

# %%
document_section = 'Risk Factors'
ticker = "JNJ"
year = 2015
previous_year = 2016
doc = next(cb.document_search(company_identifiers=[ticker], document_name=document_section, year=year)).get_contents()
previous_doc = next(cb.document_search(company_identifiers=[ticker], document_name=document_section, year=previous_year)).get_contents()
display(HTML(cb.html_diff(doc, previous_doc)))
# Out:
# <span>Item 1A.<br> RISK FACTORS <br>The Company faces a number of uncertainties and risks that are difficult to predict and many of which are outside of the Company's control. In addition to the other information in this </span><del style="background:#ffe6e6;">R</del><ins style="background:#e6ffe6;">r</ins><span>eport and the Company's other filings with the SEC, investors should consider carefully the factors set forth </span><ins style="background:#e6ffe6;">below. Investors should be aware that </ins><span>i</span><ins style="background:#e6ffe6;">t is </ins><span>n</span><ins style="background:#e6ffe6;">ot</ins><span> </span><ins style="background:#e6ffe6;">possible to predict or identify all such factors and that the following is not meant to be a complete discussion of all potential risks or uncertainties. If known or unknown risks or uncertainties materialize, the Company's business, results of operations or financial condition could be adversely affected, potentially in a material way.<br><br> <br> <br> 4 <br> <br><br>One of the Company's key products, R</ins><span>E</span><ins style="background:#e6ffe6;">MICADE (infli</ins><span>x</span><ins style="background:#e6ffe6;">imab), is experiencing biosimilar competition, w</ins><span>hi</span><ins style="background:#e6ffe6;">ch will result in a reduction in U.S. sales of REMICADE. <br><br>The Company has experienced significant challenges to patents covering its largest product, REMICADE (inflixima</ins><span>b</span><ins style="background:#e6ffe6;">) (account</ins><span>i</span><ins style="background:#e6ffe6;">ng for approxima</ins><span>t</span><ins style="background:#e6ffe6;">ely</ins><span> 9</span><del style="background:#ffe6e6;">9</del><ins style="background:#e6ffe6;">.7% of the Company's total revenues for fiscal 2016), and continues to assert certain patents related</ins><span> to th</span><ins style="background:#e6ffe6;">e product. In Apr</ins><span>i</span><ins style="background:#e6ffe6;">l 2016, the FDA approved for </ins><span>s</span><ins style="background:#e6ffe6;">ale in the United States an infliximab biosimilar to be marketed by a subsidiary of Pfizer Inc. In October 2016, the notice of launch period under the U.S. Biologics Price Competition and Innovation Act (the BPCIA) passed and in November 2016 Pfizer began shipment of an infliximab biosimilar to wholesalers in the United States. Sales of an infliximab biosimilar in the U.S. market will result in a reduction in U.S. sales of</ins><span> R</span><ins style="background:#e6ffe6;">EMICADE. <br><br>Global sal</ins><span>e</span><ins style="background:#e6ffe6;">s in the Com</ins><span>p</span><ins style="background:#e6ffe6;">any's pharmaceutical and medical devices segments may be negatively impacted by healthcare ref</ins><span>or</span><ins style="background:#e6ffe6;">ms and increasing pricing pressures.<br><br>Sales of </ins><span>t</span><ins style="background:#e6ffe6;">he Company's pharmaceutical and medical device products are significantly affected by reimbursements by third-party payers such as government healthcare programs, private insurance plans and managed care organizations. As part of various efforts to contain healthcare costs, these payers are putting downward pressure on prices at which products will be reimbursed</ins><span>. In</span><ins style="background:#e6ffe6;"> the United States, increased purchasing power of entities that negotiate on behalf of Medicare, Medicaid, and pri</ins><span>v</span><ins style="background:#e6ffe6;">at</ins><span>e</span><ins style="background:#e6ffe6;"> </ins><span>s</span><ins style="background:#e6ffe6;">ec</ins><span>tor</span><ins style="background:#e6ffe6;"> beneficiarie</ins><span>s</span><ins style="background:#e6ffe6;">,</ins><span> </span><ins style="background:#e6ffe6;">in part due to continued con</ins><span>s</span><ins style="background:#e6ffe6;">olidation among </ins><span>h</span><ins style="background:#e6ffe6;">ealth care providers, c</ins><sp ...

# %% [markdown]
# ## Review Changes
# #### The .607 distance between JNJ's 2015 and 2016 risk factors indicates a substantial change.  We verify the change on Calcbench's [disclosure page](https://www.calcbench.com/query/footnotes?pg_classificationMethod=tickers&pg_tickers=JNJ&doc_searchingBy=footnoteType&doc_footnoteType=1110&doc_selectedDisclosure=b-648365_section111&pc_year=2016&pc_periodType=Annual&pc_useFiscalPeriod=false&pc_rangeOption=Single%20Period&pc_dateRange=%5Bobject%20Object%5D).
# ![Diff](https://dl.dropboxusercontent.com/s/vjd382gr4vvhvuh/diff.png?raw=1)
