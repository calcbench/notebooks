# %%
response <- httr::with_verbose(httr::POST('https://www.calcbench.com/account/LogOnAjax', 
                 body = list(email = 'andrew@calcbench.com', strng = 'CALCBENCH_PASSWORD'), 
                 encode = 'json'))

# %%
response <- POST('https://www.calcbench.com/api/companies', body = list(index = jsonlite::unbox('DJIA')), encode='json')

# %%
content(response)
# Out:
# [[1]]
# [[1]]$entity_id
# [1] 5128
#
# [[1]]$entity_name
# [1] "3M Co"
#
# [[1]]$ticker
# [1] "MMM"
#
# [[1]]$first_filing
# [1] "2009-07-31T00:00:00"
#
# [[1]]$most_recent_filing
# [1] "2018-02-08T00:00:00"
#
# [[1]]$most_recent_full_year_end
# [1] "2017-12-31T00:00:00"
#
# [[1]]$most_recent_fiscal_year
# [1] 2017
#
# [[1]]$sic_code
# [1] 3841
#
# [[1]]$naics_code
# [1] 332994
#
# [[1]]$cik_code
# [1] "0000066740"
#
# [[1]]$most_recent_complete_calendar_year
# [1] 2017
#
# [[1]]$most_recent_complete_fiscal_year
# [1] 2017
#
# [[1]]$most_recent_filing_calendar_period
# [1] 4
#
# [[1]]$most_recent_filing_calendar_year
# [1] 2017
#
#
# [[2]]
# [[2]]$entity_id
# [1] 5010
#
# [[2]]$entity_name
# [1] "American Express Co"
#
# [[2]]$ticker
# [1] "AXP"
#
# [[2]]$first_filing
# [1] "2009-09-02T00:00:00"
#
# [[2]]$most_recent_filing
# [1] "2018-02-16T00:00:00"
#
# [[2]]$most_recent_full_year_end
# [1] "2017-12-31T00:00:00"
#
# [[2]]$most_recent_fiscal_year
# [1] 2017
#
# [[2]]$sic_code
# ...
