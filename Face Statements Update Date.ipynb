# %%
import calcbench as cb
import datetime

# %%
income_statement_metrics = [
    'Revenue',
    'CostOfRevenue',
    'GrossProfit',
    'SGAExpense',
    'OperatingExpenses',
    'OperatingIncome',
    'EBIT',
    'InterestExpense',
    'IncomeTaxes',
    'NetIncome'
]

balance_sheet_metrics = [
    'Cash',
    'AccountsReceivable',
    'Inventory',
    'CurrentAssets',
    'PPE',
    'Goodwill',
    'LongTermInvestments',
    'Assets',
    'AccountsPayable',
    'ShortTermDebt',
    'DeferredRevenue',
    'CurrentLiabilities',
    'LongTermDebt',
    'Liabilities',
    'RetainedEarnings',
    'TreasuryStockValue',
    'StockHoldersEquity',

]

# %%
cb.normalized_raw(entire_universe=True, metrics=income_statement_metrics, update_date=datetime.date(2017, 1, 23), all_history=True)
# Out:
# [{'CIK': None,
#   'calcbench_entity_id': 0,
#   'calendar_period': 4,
#   'calendar_year': 2016,
#   'fiscal_period': 2,
#   'fiscal_year': 2017,
#   'metric': 'CostOfRevenue',
#   'ticker': 'AIVN',
#   'value': 24263.0},
#  {'CIK': None,
#   'calcbench_entity_id': 0,
#   'calendar_period': 4,
#   'calendar_year': 2016,
#   'fiscal_period': 2,
#   'fiscal_year': 2017,
#   'metric': 'EBIT',
#   'ticker': 'AIVN',
#   'value': -234689.0},
#  {'CIK': None,
#   'calcbench_entity_id': 0,
#   'calendar_period': 4,
#   'calendar_year': 2016,
#   'fiscal_period': 2,
#   'fiscal_year': 2017,
#   'metric': 'GrossProfit',
#   'ticker': 'AIVN',
#   'value': -3098.0},
#  {'CIK': None,
#   'calcbench_entity_id': 0,
#   'calendar_period': 4,
#   'calendar_year': 2016,
#   'fiscal_period': 2,
#   'fiscal_year': 2017,
#   'metric': 'InterestExpense',
#   'ticker': 'AIVN',
#   'value': 1296.0},
#  {'CIK': None,
#   'calcbench_entity_id': 0,
#   'calendar_period': 4,
#   'calendar_year': 2016,
# ...

# %%
cb.normalized_raw(entire_universe=True, metrics=balance_sheet_metrics, update_date=datetime.date(2017, 1, 23), all_history=True)
# Out:
# [{'CIK': None,
#   'calcbench_entity_id': 0,
#   'calendar_period': 4,
#   'calendar_year': 2016,
#   'fiscal_period': 2,
#   'fiscal_year': 2017,
#   'metric': 'AccountsPayable',
#   'ticker': 'AIVN',
#   'value': 150764.0},
#  {'CIK': None,
#   'calcbench_entity_id': 0,
#   'calendar_period': 4,
#   'calendar_year': 2016,
#   'fiscal_period': 2,
#   'fiscal_year': 2017,
#   'metric': 'AccountsReceivable',
#   'ticker': 'AIVN',
#   'value': 60559.0},
#  {'CIK': None,
#   'calcbench_entity_id': 0,
#   'calendar_period': 4,
#   'calendar_year': 2016,
#   'fiscal_period': 2,
#   'fiscal_year': 2017,
#   'metric': 'Assets',
#   'ticker': 'AIVN',
#   'value': 1589264.0},
#  {'CIK': None,
#   'calcbench_entity_id': 0,
#   'calendar_period': 4,
#   'calendar_year': 2016,
#   'fiscal_period': 2,
#   'fiscal_year': 2017,
#   'metric': 'Cash',
#   'ticker': 'AIVN',
#   'value': 52636.0},
#  {'CIK': None,
#   'calcbench_entity_id': 0,
#   'calendar_period': 4,
#   'calendar_year': 2016,
# ...
