# %%
import calcbench as cb
from calcbench.models.revisions import Revisions

# %%
cb.api_client._rig_for_testing("localhost")

# %%
tickers = cb.tickers(index="DJIA")

# %%
d = cb.standardized_raw(
    include_trace=True,
    pit_V2=True,
    company_identifiers=tickers,
    all_history=True,
    metrics=["UnrecognizedTaxBenefits"],
    point_in_time=True,
    revisions=Revisions.MostRecent,
    XBRL_only=True,
)

# %%
for t in d:
    print(
        t.ticker,
        t.fiscal_year,
        t.fiscal_period,
        t.metric,
        ",".join(str(f) for f in t.trace_facts) if t.trace_facts else "none",
    )
# Out:
# DIS 2017 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=832000000.0 fact_id=None dimensions=None
# DIS 2018 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=800000000.0 fact_id=None dimensions=None
# DIS 2018 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=900000000.0 fact_id=None dimensions=None
# DIS 2018 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=900000000.0 fact_id=None dimensions=None
# DIS 2018 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=648000000.0 fact_id=None dimensions=None
# DIS 2019 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=700000000.0 fact_id=None dimensions=None
# DIS 2016 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=844000000.0 fact_id=None dimensions=None
# DIS 2016 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=854000000.0 fact_id=None dimensions=None
# DIS 2016 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=880000000.0 fact_id=None dimensions=None
# DIS 2017 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=818000000.0 fact_id=None dimensions=None
# DIS 2017 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=804000000.0 fact_id=None dimensions=None
# DIS 2020 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2740000000.0 fact_id=None dimensions=None
# DIS 2021 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2641000000.0 fact_id=None dimensions=None
# DIS 2022 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2600000000.0 fact_id=None dimensions=None
# DIS 2022 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2400000000.0 fact_id=None dimensions=None
# DIS 2022 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2400000000.0 fact_id=None dimensions=None
# DIS 2019 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2700000000.0 fact_id=None dimensions=None
# DIS 2020 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2900000000.0 fact_id=None dimensions=None
# DIS 2019 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2952000000.0 fact_id=None dimensions=None
# DIS 2015 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=822000000.0 fact_id=None dimensions=None
# DIS 2014 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=803000000.0 fact_id=None dimensions=None
# DIS 2015 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=948000000.0 fact_id=None dimensions=None
# DIS 2015 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=860000000.0 fact_id=None dimensions=None
# DIS 2013 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1084000000.0 fact_id=None dimensions=None
# DIS 2012 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=668000000.0 fact_id=None dimensions=None
# DIS 2014 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=923000000.0 fact_id=None dimensions=None
# DIS 2014 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=755000000.0 fact_id=None dimensions=None
# DIS 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=912000000.0 fact_id=None dimensions=None
# DIS 2009 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=686000000.0 fact_id=None dimensions=None
# DIS 2010 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=680000000.0 fact_id=None dimensions=None
# DIS 2008 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=655000000.0 fact_id=None dimensions=None
# DIS 2011 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=718000000.0 fact_id=None dimensions=None
# DIS 2020 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2900000000.0 fact_id=None dimensions=None
# DIS 2020 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2900000000.0 fact_id=None dimensions=None
# DIS 2021 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2500000000.0 fact_id=None dimensions=None
# DIS 2017 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=821000000.0 fact_id=None dimensions=None
# DIS 2016 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=894000000.0 fact_id=None dimensions=None
# DIS 2019 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2800000000.0 fact_id=None dimensions=None
# DIS 2013 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1120000000.0 fact_id=None dimensions=None
# AMZN 2019 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3600000000.0 fact_id=None dimensions=None
# AMZN 2018 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3414000000.0 fact_id=None dimensions=None
# AMZN 2017 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2309000000.0 fact_id=None dimensions=None
# AMZN 2017 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1900000000.0 fact_id=None dimensions=None
# AMZN 2017 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2100000000.0 fact_id=None dimensions=None
# AMZN 2019 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3700000000.0 fact_id=None dimensions=None
# AMZN 2021 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2900000000.0 fact_id=None dimensions=None
# AMZN 2021 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3200000000.0 fact_id=None dimensions=None
# AMZN 2022 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3300000000.0 fact_id=None dimensions=None
# AMZN 2019 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3923000000.0 fact_id=None dimensions=None
# AMZN 2020 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3700000000.0 fact_id=None dimensions=None
# AMZN 2009 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=181000000.0 fact_id=None dimensions=None
# AMZN 2010 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=207000000.0 fact_id=None dimensions=None
# AMZN 2015 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=895000000.0 fact_id=None dimensions=None
# AMZN 2012 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=294000000.0 fact_id=None dimensions=None
# AMZN 2012 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=250000000.0 fact_id=None dimensions=None
# AMZN 2012 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=253000000.0 fact_id=None dimensions=None
# AMZN 2010 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=213000000.0 fact_id=None dimensions=None
# AMZN 2018 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3300000000.0 fact_id=None dimensions=None
# AMZN 2018 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3400000000.0 fact_id=None dimensions=None
# AMZN 2018 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2600000000.0 fact_id=None dimensions=None
# AMZN 2016 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1710000000.0 fact_id=None dimensions=None
# AMZN 2017 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1800000000.0 fact_id=None dimensions=None
# AMZN 2016 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1700000000.0 fact_id=None dimensions=None
# AMZN 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1181000000.0 fact_id=None dimensions=None
# AMZN 2021 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2800000000.0 fact_id=None dimensions=None
# AMZN 2021 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3000000000.0 fact_id=None dimensions=None
# AMZN 2020 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2820000000.0 fact_id=None dimensions=None
# AMZN 2022 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3300000000.0 fact_id=None dimensions=None
# AMZN 2020 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3800000000.0 fact_id=None dimensions=None
# AMZN 2019 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3800000000.0 fact_id=None dimensions=None
# AMZN 2020 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3000000000.0 fact_id=None dimensions=None
# AMZN 2011 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=229000000.0 fact_id=None dimensions=None
# AMZN 2012 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=233000000.0 fact_id=None dimensions=None
# AMZN 2011 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=222000000.0 fact_id=None dimensions=None
# AMZN 2011 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=218000000.0 fact_id=None dimensions=None
# AMZN 2011 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=228000000.0 fact_id=None dimensions=None
# AMZN 2013 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=314000000.0 fact_id=None dimensions=None
# AMZN 2013 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=317000000.0 fact_id=None dimensions=None
# AMZN 2016 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1600000000.0 fact_id=None dimensions=None
# AMZN 2013 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=336000000.0 fact_id=None dimensions=None
# AMZN 2014 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=626000000.0 fact_id=None dimensions=None
# AMZN 2014 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=590000000.0 fact_id=None dimensions=None
# AMZN 2014 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=455000000.0 fact_id=None dimensions=None
# AMZN 2013 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=407000000.0 fact_id=None dimensions=None
# AMZN 2008 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=166000000.0 fact_id=None dimensions=None
# AMZN 2010 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=206000000.0 fact_id=None dimensions=None
# AMZN 2015 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=854000000.0 fact_id=None dimensions=None
# AMZN 2015 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=726000000.0 fact_id=None dimensions=None
# AMZN 2014 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=710000000.0 fact_id=None dimensions=None
# AMZN 2016 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1300000000.0 fact_id=None dimensions=None
# VZ 2020 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2944000000.0 fact_id=None dimensions=None
# VZ 2011 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3078000000.0 fact_id=None dimensions=None
# VZ 2014 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1823000000.0 fact_id=None dimensions=None
# VZ 2012 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2943000000.0 fact_id=None dimensions=None
# VZ 2010 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3242000000.0 fact_id=None dimensions=None
# VZ 2009 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3400000000.0 fact_id=None dimensions=None
# VZ 2008 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2622000000.0 fact_id=None dimensions=None
# VZ 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1635000000.0 fact_id=None dimensions=None
# VZ 2016 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1902000000.0 fact_id=None dimensions=None
# VZ 2017 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2355000000.0 fact_id=None dimensions=None
# VZ 2021 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3134000000.0 fact_id=None dimensions=None
# VZ 2019 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2870000000.0 fact_id=None dimensions=None
# VZ 2018 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2871000000.0 fact_id=None dimensions=None
# VZ 2013 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2130000000.0 fact_id=None dimensions=None
# WMT 2021 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3135000000.0 fact_id=None dimensions=None
# WMT 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3245000000.0 fact_id=None dimensions=None
# WMT 2020 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1817000000.0 fact_id=None dimensions=None
# WMT 2011 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=795000000.0 fact_id=None dimensions=None
# WMT 2010 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1019000000.0 fact_id=None dimensions=None
# WMT 2009 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1017000000.0 fact_id=None dimensions=None
# WMT 2012 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=611000000.0 fact_id=None dimensions=None
# WMT 2014 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=763000000.0 fact_id=None dimensions=None
# WMT 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=838000000.0 fact_id=None dimensions=None
# WMT 2013 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=818000000.0 fact_id=None dimensions=None
# WMT 2018 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1010000000.0 fact_id=None dimensions=None
# WMT 2017 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1050000000.0 fact_id=None dimensions=None
# WMT 2019 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1305000000.0 fact_id=None dimensions=None
# WMT 2016 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=607000000.0 fact_id=None dimensions=None
# V 2020 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2579000000.0 fact_id=None dimensions=None
# V 2018 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1658000000.0 fact_id=None dimensions=None
# V 2017 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1353000000.0 fact_id=None dimensions=None
# V 2016 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1160000000.0 fact_id=None dimensions=None
# V 2019 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2234000000.0 fact_id=None dimensions=None
# MMM 2019 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1167000000.0 fact_id=None dimensions=None
# MMM 2020 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1113000000.0 fact_id=None dimensions=None
# MSFT 2017 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=11737000000.0 fact_id=None dimensions=None
# MSFT 2019 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=13146000000.0 fact_id=None dimensions=None
# MSFT 2011 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=6935000000.0 fact_id=None dimensions=None
# MMM 2018 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=647000000.0 fact_id=None dimensions=None
# MMM 2021 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1071000000.0 fact_id=None dimensions=None
# MMM 2011 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=594000000.0 fact_id=None dimensions=None
# MMM 2012 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=528000000.0 fact_id=None dimensions=None
# MSFT 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=9599000000.0 fact_id=None dimensions=None
# MMM 2008 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=557000000.0 fact_id=None dimensions=None
# MMM 2009 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=618000000.0 fact_id=None dimensions=None
# MMM 2010 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=622000000.0 fact_id=None dimensions=None
# MMM 2016 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=319000000.0 fact_id=None dimensions=None
# MMM 2017 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=530000000.0 fact_id=None dimensions=None
# MMM 2013 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=659000000.0 fact_id=None dimensions=None
# MMM 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=381000000.0 fact_id=None dimensions=None
# MMM 2014 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=583000000.0 fact_id=None dimensions=None
# V 2021 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2488000000.0 fact_id=None dimensions=None
# V 2012 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=679000000.0 fact_id=None dimensions=None
# V 2011 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=850000000.0 fact_id=None dimensions=None
# V 2013 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1023000000.0 fact_id=None dimensions=None
# V 2009 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=439000000.0 fact_id=None dimensions=None
# V 2008 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=407000000.0 fact_id=None dimensions=None
# V 2010 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=545000000.0 fact_id=None dimensions=None
# V 2014 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1303000000.0 fact_id=None dimensions=None
# V 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1051000000.0 fact_id=None dimensions=None
# MSFT 2018 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=11961000000.0 fact_id=None dimensions=None
# MSFT 2016 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=10164000000.0 fact_id=None dimensions=None
# MSFT 2021 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=14550000000.0 fact_id=None dimensions=None
# MSFT 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=15593000000.0 fact_id=None dimensions=None
# MSFT 2020 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=13792000000.0 fact_id=None dimensions=None
# MSFT 2012 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=7202000000.0 fact_id=None dimensions=None
# MSFT 2008 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3195000000.0 fact_id=None dimensions=None
# MSFT 2009 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=5403000000.0 fact_id=None dimensions=None
# MSFT 2010 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=6542000000.0 fact_id=None dimensions=None
# MSFT 2014 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=8714000000.0 fact_id=None dimensions=None
# MSFT 2013 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=8648000000.0 fact_id=None dimensions=None
# V 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2683000000.0 fact_id=None dimensions=None
# AMZN 2023 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=5000000000.0 fact_id=None dimensions=None
# AMZN 2023 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=5000000000.0 fact_id=None dimensions=None
# MMM 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=927000000.0 fact_id=None dimensions=None
# CRM 2014 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=102275000.0 fact_id=None dimensions=None
# CRM 2013 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=75144000.0 fact_id=None dimensions=None
# CRM 2018 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=304000000.0 fact_id=None dimensions=None
# CRM 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=146188000.0 fact_id=None dimensions=None
# CRM 2019 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=852000000.0 fact_id=None dimensions=None
# CRM 2021 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1479000000.0 fact_id=None dimensions=None
# CRM 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1822000000.0 fact_id=None dimensions=None
# CRM 2020 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1433000000.0 fact_id=None dimensions=None
# CRM 2012 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=51971000.0 fact_id=None dimensions=None
# CRM 2012 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=13100000.0 fact_id=None dimensions=None
# CRM 2011 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=27462000.0 fact_id=None dimensions=None
# CRM 2010 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=22053000.0 fact_id=None dimensions=None
# CRM 2009 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=16472000.0 fact_id=None dimensions=None
# BA 2018 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2412000000.0 fact_id=None dimensions=None
# BA 2016 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1378000000.0 fact_id=None dimensions=None
# BA 2016 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1557000000.0 fact_id=None dimensions=None
# BA 2017 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1736000000.0 fact_id=None dimensions=None
# BA 2020 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=966000000.0 fact_id=None dimensions=None
# BA 2021 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=858000000.0 fact_id=None dimensions=None
# BA 2019 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1476000000.0 fact_id=None dimensions=None
# BA 2011 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=939000000.0 fact_id=None dimensions=None
# BA 2012 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1055000000.0 fact_id=None dimensions=None
# BA 2010 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1198000000.0 fact_id=None dimensions=None
# BA 2009 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1787000000.0 fact_id=None dimensions=None
# BA 2008 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1453000000.0 fact_id=None dimensions=None
# BA 2014 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1526000000.0 fact_id=None dimensions=None
# BA 2014 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1312000000.0 fact_id=None dimensions=None
# BA 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1617000000.0 fact_id=None dimensions=None
# BA 2014 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1420000000.0 fact_id=None dimensions=None
# BA 2013 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1141000000.0 fact_id=None dimensions=None
# CAT 2020 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1759000000.0 fact_id=None dimensions=None
# CAT 2021 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1886000000.0 fact_id=None dimensions=None
# CAT 2019 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1778000000.0 fact_id=None dimensions=None
# CAT 2011 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=958000000.0 fact_id=None dimensions=None
# CAT 2012 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=715000000.0 fact_id=None dimensions=None
# CAT 2008 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=803000000.0 fact_id=None dimensions=None
# CAT 2009 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=761000000.0 fact_id=None dimensions=None
# CAT 2010 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=789000000.0 fact_id=None dimensions=None
# CAT 2014 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=846000000.0 fact_id=None dimensions=None
# CAT 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=968000000.0 fact_id=None dimensions=None
# CAT 2013 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=759000000.0 fact_id=None dimensions=None
# CAT 2017 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1286000000.0 fact_id=None dimensions=None
# CAT 2018 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1796000000.0 fact_id=None dimensions=None
# JNJ 2015 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2600000000.0 fact_id=None dimensions=None
# JNJ 2015 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2500000000.0 fact_id=None dimensions=None
# CAT 2016 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1032000000.0 fact_id=None dimensions=None
# JPM 2017 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=4747000000.0 fact_id=None dimensions=None
# JPM 2016 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3450000000.0 fact_id=None dimensions=None
# JPM 2018 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=4861000000.0 fact_id=None dimensions=None
# JPM 2021 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=4636000000.0 fact_id=None dimensions=None
# JPM 2019 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=4024000000.0 fact_id=None dimensions=None
# JPM 2020 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=4250000000.0 fact_id=None dimensions=None
# JPM 2011 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=7189000000.0 fact_id=None dimensions=None
# JPM 2012 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=7158000000.0 fact_id=None dimensions=None
# JPM 2010 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=7767000000.0 fact_id=None dimensions=None
# JPM 2009 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=6608000000.0 fact_id=None dimensions=None
# JPM 2008 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=5894000000.0 fact_id=None dimensions=None
# JPM 2014 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=4911000000.0 fact_id=None dimensions=None
# JPM 2013 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=5535000000.0 fact_id=None dimensions=None
# JPM 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3497000000.0 fact_id=None dimensions=None
# JNJ 2018 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3200000000.0 fact_id=None dimensions=None
# JNJ 2018 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3200000000.0 fact_id=None dimensions=None
# JNJ 2018 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3200000000.0 fact_id=None dimensions=None
# JNJ 2019 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3400000000.0 fact_id=None dimensions=None
# JNJ 2018 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3326000000.0 fact_id=None dimensions=None
# JNJ 2016 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3041000000.0 fact_id=None dimensions=None
# JNJ 2016 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3100000000.0 fact_id=None dimensions=None
# JNJ 2016 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3100000000.0 fact_id=None dimensions=None
# JNJ 2017 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3300000000.0 fact_id=None dimensions=None
# JNJ 2017 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3151000000.0 fact_id=None dimensions=None
# JNJ 2017 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3100000000.0 fact_id=None dimensions=None
# JNJ 2017 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3200000000.0 fact_id=None dimensions=None
# JNJ 2021 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3300000000.0 fact_id=None dimensions=None
# JNJ 2021 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3300000000.0 fact_id=None dimensions=None
# JNJ 2020 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3260000000.0 fact_id=None dimensions=None
# JNJ 2021 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3300000000.0 fact_id=None dimensions=None
# JNJ 2022 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3300000000.0 fact_id=None dimensions=None
# JNJ 2022 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3400000000.0 fact_id=None dimensions=None
# JNJ 2021 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3210000000.0 fact_id=None dimensions=None
# JNJ 2019 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3853000000.0 fact_id=None dimensions=None
# JNJ 2019 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3300000000.0 fact_id=None dimensions=None
# JNJ 2019 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3600000000.0 fact_id=None dimensions=None
# JNJ 2020 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3300000000.0 fact_id=None dimensions=None
# JNJ 2020 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3200000000.0 fact_id=None dimensions=None
# JNJ 2020 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3100000000.0 fact_id=None dimensions=None
# JNJ 2016 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3100000000.0 fact_id=None dimensions=None
# JNJ 2011 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2699000000.0 fact_id=None dimensions=None
# JNJ 2012 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3054000000.0 fact_id=None dimensions=None
# JNJ 2008 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1978000000.0 fact_id=None dimensions=None
# JNJ 2010 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2307000000.0 fact_id=None dimensions=None
# JNJ 2009 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2403000000.0 fact_id=None dimensions=None
# JNJ 2013 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2900000000.0 fact_id=None dimensions=None
# JNJ 2013 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2400000000.0 fact_id=None dimensions=None
# JNJ 2013 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2800000000.0 fact_id=None dimensions=None
# JNJ 2014 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2300000000.0 fact_id=None dimensions=None
# JNJ 2014 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2200000000.0 fact_id=None dimensions=None
# JNJ 2013 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2729000000.0 fact_id=None dimensions=None
# JNJ 2014 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2300000000.0 fact_id=None dimensions=None
# JNJ 2014 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2465000000.0 fact_id=None dimensions=None
# JNJ 2015 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2600000000.0 fact_id=None dimensions=None
# JNJ 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3080000000.0 fact_id=None dimensions=None
# KO 2009 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=354000000.0 fact_id=None dimensions=None
# KO 2010 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=387000000.0 fact_id=None dimensions=None
# KO 2014 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=211000000.0 fact_id=None dimensions=None
# KO 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=168000000.0 fact_id=None dimensions=None
# KO 2013 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=230000000.0 fact_id=None dimensions=None
# KO 2018 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=336000000.0 fact_id=None dimensions=None
# KO 2016 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=302000000.0 fact_id=None dimensions=None
# KO 2016 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=341000000.0 fact_id=None dimensions=None
# KO 2016 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=343000000.0 fact_id=None dimensions=None
# KO 2017 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=331000000.0 fact_id=None dimensions=None
# KO 2020 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=915000000.0 fact_id=None dimensions=None
# KO 2021 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=906000000.0 fact_id=None dimensions=None
# KO 2019 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=392000000.0 fact_id=None dimensions=None
# KO 2011 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=320000000.0 fact_id=None dimensions=None
# KO 2012 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=328000000.0 fact_id=None dimensions=None
# KO 2012 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=302000000.0 fact_id=None dimensions=None
# KO 2012 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=373000000.0 fact_id=None dimensions=None
# KO 2012 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=379000000.0 fact_id=None dimensions=None
# KO 2008 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=369000000.0 fact_id=None dimensions=None
# MRK 2018 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1893000000.0 fact_id=None dimensions=None
# MRK 2016 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3494000000.0 fact_id=None dimensions=None
# MRK 2017 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1723000000.0 fact_id=None dimensions=None
# MRK 2021 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1529000000.0 fact_id=None dimensions=None
# MRK 2019 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1225000000.0 fact_id=None dimensions=None
# MRK 2020 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1537000000.0 fact_id=None dimensions=None
# MRK 2011 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=4277000000.0 fact_id=None dimensions=None
# MRK 2010 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=4919000000.0 fact_id=None dimensions=None
# MRK 2009 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=4743000000.0 fact_id=None dimensions=None
# MRK 2008 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3665000000.0 fact_id=None dimensions=None
# MRK 2014 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3534000000.0 fact_id=None dimensions=None
# MRK 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3448000000.0 fact_id=None dimensions=None
# MRK 2012 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=4425000000.0 fact_id=None dimensions=None
# MRK 2013 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3503000000.0 fact_id=None dimensions=None
# AMGN 2013 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1415000000.0 fact_id=None dimensions=None
# AMGN 2017 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2953000000.0 fact_id=None dimensions=None
# AMGN 2018 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3061000000.0 fact_id=None dimensions=None
# AMGN 2016 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2543000000.0 fact_id=None dimensions=None
# AMGN 2020 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3352000000.0 fact_id=None dimensions=None
# AMGN 2021 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3546000000.0 fact_id=None dimensions=None
# AMGN 2019 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3287000000.0 fact_id=None dimensions=None
# AMGN 2011 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=975000000.0 fact_id=None dimensions=None
# AMGN 2012 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1200000000.0 fact_id=None dimensions=None
# AMGN 2009 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1140000000.0 fact_id=None dimensions=None
# AMGN 2008 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1113000000.0 fact_id=None dimensions=None
# AMGN 2010 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=920000000.0 fact_id=None dimensions=None
# AMGN 2014 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1772000000.0 fact_id=None dimensions=None
# AMGN 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2114000000.0 fact_id=None dimensions=None
# NKE 2018 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=718000000.0 fact_id=None dimensions=None
# NKE 2018 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=514000000.0 fact_id=None dimensions=None
# NKE 2018 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=498000000.0 fact_id=None dimensions=None
# ...
# GS 2009 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1925000000.0 fact_id=None dimensions=None
# GS 2010 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2081000000.0 fact_id=None dimensions=None
# GS 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=825000000.0 fact_id=None dimensions=None
# GS 2013 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1765000000.0 fact_id=None dimensions=None
# GS 2014 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=871000000.0 fact_id=None dimensions=None
# CVX 2011 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3481000000.0 fact_id=None dimensions=None
# CVX 2010 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3507000000.0 fact_id=None dimensions=None
# CVX 2009 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3195000000.0 fact_id=None dimensions=None
# CVX 2008 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2696000000.0 fact_id=None dimensions=None
# CVX 2014 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3552000000.0 fact_id=None dimensions=None
# CVX 2017 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=4828000000.0 fact_id=None dimensions=None
# CVX 2018 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=5070000000.0 fact_id=None dimensions=None
# CVX 2016 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3031000000.0 fact_id=None dimensions=None
# CVX 2020 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=5018000000.0 fact_id=None dimensions=None
# CVX 2021 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=5288000000.0 fact_id=None dimensions=None
# CVX 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3042000000.0 fact_id=None dimensions=None
# CVX 2012 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3071000000.0 fact_id=None dimensions=None
# CVX 2013 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3848000000.0 fact_id=None dimensions=None
# CVX 2019 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=4987000000.0 fact_id=None dimensions=None
# DOW 2020 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=373000000.0 fact_id=None dimensions=None
# DOW 2019 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=319000000.0 fact_id=None dimensions=None
# DOW 2021 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=580000000.0 fact_id=None dimensions=None
# DOW 2017 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=255000000.0 fact_id=None dimensions=None
# DOW 2017 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=239000000.0 fact_id=None dimensions=None
# DOW 2016 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=231000000.0 fact_id=None dimensions=None
# DOW 2015 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=280000000.0 fact_id=None dimensions=None
# DOW 2018 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=314000000.0 fact_id=None dimensions=None
# AMZN 2022 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3400000000.0 fact_id=None dimensions=None
# AAPL 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=16758000000.0 fact_id=None dimensions=None
# MCD 2022 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=616400000.0 fact_id=None dimensions=None
# DIS 2022 0 UnrecognizedTaxBenefits none
# CSCO 2023 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3300000000.0 fact_id=None dimensions=None
# BA 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=915000000.0 fact_id=None dimensions=None
# DOW 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=520000000.0 fact_id=None dimensions=None
# AMZN 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=4002000000.0 fact_id=None dimensions=None
# NKE 2023 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=867000000.0 fact_id=None dimensions=None
# VZ 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2812000000.0 fact_id=None dimensions=None
# AXP 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=962000000.0 fact_id=None dimensions=None
# DIS 2023 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2600000000.0 fact_id=None dimensions=None
# CAT 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1140000000.0 fact_id=None dimensions=None
# TRV 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=9000000.0 fact_id=None dimensions=None
# JNJ 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3716000000.0 fact_id=None dimensions=None
# KO 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=926000000.0 fact_id=None dimensions=None
# JPM 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=5043000000.0 fact_id=None dimensions=None
# CSCO 2023 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3400000000.0 fact_id=None dimensions=None
# CVX 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=5323000000.0 fact_id=None dimensions=None
# GS 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1533000000.0 fact_id=None dimensions=None
# MCD 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=647000000.0 fact_id=None dimensions=None
# IBM 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=8728000000.0 fact_id=None dimensions=None
# CRM 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1975000000.0 fact_id=None dimensions=None
# WMT 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3307000000.0 fact_id=None dimensions=None
# HD 2022 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=643000000.0 fact_id=None dimensions=None
# NKE 2023 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=941000000.0 fact_id=None dimensions=None
# JNJ 2023 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1700000000.0 fact_id=None dimensions=None
# AMZN 2023 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=4200000000.0 fact_id=None dimensions=None
# DIS 2023 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2700000000.0 fact_id=None dimensions=None
# CSCO 2023 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3400000000.0 fact_id=None dimensions=None
# NKE 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=936000000.0 fact_id=None dimensions=None
# JNJ 2023 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=500000000.0 fact_id=None dimensions=None
# MSFT 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=17120000000.0 fact_id=None dimensions=None
# PG 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=515000000.0 fact_id=None dimensions=None
# CSCO 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2137000000.0 fact_id=None dimensions=None
# DIS 2023 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2700000000.0 fact_id=None dimensions=None
# NKE 2024 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=931000000.0 fact_id=None dimensions=None
# JNJ 2023 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2300000000.0 fact_id=None dimensions=None
# V 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3497000000.0 fact_id=None dimensions=None
# AXP 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=875000000.0 fact_id=None dimensions=None
# AAPL 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=19454000000.0 fact_id=None dimensions=None
# CSCO 2024 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1900000000.0 fact_id=None dimensions=None
# DIS 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2500000000.0 fact_id=None dimensions=None
# NKE 2024 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=931000000.0 fact_id=None dimensions=None
# INTC 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1124000000.0 fact_id=None dimensions=None
# BA 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1131000000.0 fact_id=None dimensions=None
# AMZN 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=5228000000.0 fact_id=None dimensions=None
# MMM 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=800000000.0 fact_id=None dimensions=None
# DOW 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=513000000.0 fact_id=None dimensions=None
# DIS 2024 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2500000000.0 fact_id=None dimensions=None
# HON 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1225000000.0 fact_id=None dimensions=None
# JNJ 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2485000000.0 fact_id=None dimensions=None
# JPM 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=5401000000.0 fact_id=None dimensions=None
# VZ 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2705000000.0 fact_id=None dimensions=None
# KO 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=929000000.0 fact_id=None dimensions=None
# TRV 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=14000000.0 fact_id=None dimensions=None
# CAT 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=1223000000.0 fact_id=None dimensions=None
# CSCO 2024 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2000000000.0 fact_id=None dimensions=None
# AMGN 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=4012000000.0 fact_id=None dimensions=None
# MCD 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=587700000.0 fact_id=None dimensions=None
# CVX 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=5452000000.0 fact_id=None dimensions=None
# GS 2023 0 UnrecognizedTaxBenefits none
# MRK 2023 0 UnrecognizedTaxBenefits none
# IBM 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=8772000000.0 fact_id=None dimensions=None
# UNH 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3716000000.0 fact_id=None dimensions=None
# CRM 2024 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2083000000.0 fact_id=None dimensions=None
# WMT 2024 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=3540000000.0 fact_id=None dimensions=None
# HD 2023 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=689000000.0 fact_id=None dimensions=None
# NKE 2024 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=988000000.0 fact_id=None dimensions=None
# AMZN 2024 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=5500000000.0 fact_id=None dimensions=None
# JNJ 2024 1 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2500000000.0 fact_id=None dimensions=None
# DIS 2024 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2400000000.0 fact_id=None dimensions=None
# CSCO 2024 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2200000000.0 fact_id=None dimensions=None
# JNJ 2024 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2500000000.0 fact_id=None dimensions=None
# NKE 2024 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=990000000.0 fact_id=None dimensions=None
# MSFT 2024 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=22760000000.0 fact_id=None dimensions=None
# PG 2024 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=582000000.0 fact_id=None dimensions=None
# DIS 2024 3 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2000000000.0 fact_id=None dimensions=None
# AMZN 2024 2 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=5600000000.0 fact_id=None dimensions=None
# CSCO 2024 0 UnrecognizedTaxBenefits local_name='UnrecognizedTaxBenefits' negative_weight=False XBRL_fact_value=2156000000.0 fact_id=None dimensions=None

# %%
one_period = cb.standardized_raw(
    include_trace=True,
    pit_V2=True,
    company_identifiers=["DIS"],
    metrics=["Revenue"],
    point_in_time=True,
    revisions=Revisions.MostRecent,
    XBRL_only=True,
    year=2012,
    period=4,
    use_fiscal_period=True,
)

one_period = sorted(one_period, key=lambda d: (d.fiscal_year, d.fiscal_period))

for t in one_period:
    print(
        t.ticker,
        t.fiscal_year,
        t.fiscal_period,
        t.metric,
        ",".join(f.local_name for f in t.trace_facts) if t.trace_facts else "none",
    )
# Out:
# DIS 2012 4 Revenue ClassOfWarrantOrRightsOutstanding
