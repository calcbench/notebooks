# %% [markdown]
# # 10-K/Q Text Change Detection
# ### [The Code](https://github.com/calcbench/notebooks/blob/master/risk_factor_similarity_and_diffing-tf-idf.ipynb)

# %% [markdown]
# ## Goal
# Reduce the amount of time analysts spend reading 10-K/Qs by highlighting the sections which change the most between periods.
#
# ## Hypothesis
# The [cosine distance](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.spatial.distance.cosine.html) between [Term Frequency - Inverse Document Frequencey (TF-IDF)](http://scikit-learn.org/stable/modules/feature_extraction.html#tfidf-term-weighting) vectors of 10-K sections is a useful proxy for symantic change in 10-K sections across time.
#
#
# ## Procedure
# 1. Use the [Calcbench Python API Client](https://github.com/calcbench/python_api_client) to download document section contents from Calcbench
#
# 2. Tokenize the sections
# 3. Build TF-IDF matrices
# 4. Compute the cosine distance between each section and the same section from the previous filing/period
# 5. Render the matrix of distances with largest distances highlighted.
# 6. Review large changes by "diffing" documents with distance above a certain threshold.

# %%
import calcbench as cb
from sklearn.feature_extraction.text import TfidfVectorizer
from bs4 import BeautifulSoup
from scipy.spatial.distance import cosine
from IPython.core.display import display, HTML
import sklearn
import itertools
from tqdm import tqdm_notebook
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import colors
# Out:
# c:\users\andrew kittredge\appdata\local\programs\python\python35\lib\importlib\_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# c:\users\andrew kittredge\appdata\local\programs\python\python35\lib\importlib\_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
class NumberNormalizingVectorizer(sklearn.feature_extraction.text.TfidfVectorizer):
    def build_tokenizer(self):
        tokenize = super(NumberNormalizingVectorizer, self).build_tokenizer()
        return lambda doc: list(number_normalizer(tokenize(doc)))

# %%
def number_normalizer(tokens):
    """ Map all numeric tokens to a placeholder.

    For many applications, tokens that begin with a number are not directly
    useful, but the fact that such a token exists can be relevant.  By applying
    this form of dimensionality reduction, some methods may perform better.
    """

    return ("#NUMBER" if token[0].isdigit() else token for token in tokens)

# %%
def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = itertools.tee(iterable)
    next(b, None)
    return zip(a, b)

# %%
cb.api_client._rig_for_testing('calcbenchtest.cloudapp.net')

# %%
accession_data = cb.standardized_data(entire_universe=True, year=2017, metrics=['auditor_name', 'filer_category']).iloc[0]
kpmg_large_accelerated = accession_data.auditor_name[accession_data.auditor_name.str.contains('KPMG', case=False).fillna(False) & (accession_data.filer_category == 'Large Accelerated Filer')].index

# %%
document_section = "Management's Discussion And Analysis"
tickers = kpmg_large_accelerated
first_year = 2008
end_year = 2017
all_years = range(end_year, first_year, -1)
diffs = pd.DataFrame(index=tickers, columns=all_years)
for ticker in tqdm_notebook(tickers):
    ten_K_sections = (d for d in cb.document_search(company_identifiers=[ticker],
                                                document_name=document_section,
                                                all_history=True) if d['fiscal_period'] == 'Y' and d['fiscal_year'] in all_years and d['document_type'] == '10-K')
    sorted_disclosures = sorted(ten_K_sections, key=lambda d: d['fiscal_year'])
    year_pairs = pairwise(sorted_disclosures)
    for last_year, this_year in year_pairs:
        text_last_year = BeautifulSoup(last_year.get_contents(), 'html.parser').text
        text_this_year = BeautifulSoup(this_year.get_contents(), 'html.parser').text
        vectorizer = NumberNormalizingVectorizer(stop_words='english')
        X = vectorizer.fit_transform([text_this_year, text_last_year])
        distance = cosine(X[0].todense(), X[1].todense())
        diffs[this_year['fiscal_year']][ticker] = distance
# Out:
# HBox(children=(IntProgress(value=0, max=420), HTML(value='')))
# c:\users\andrew kittredge\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1059: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %%
def background_gradient(s, m, M, cmap='PuBu', low=0, high=0):
    # from https://stackoverflow.com/questions/38931566/pandas-style-background-gradient-both-rows-and-columns
    rng = M - m
    norm = colors.Normalize(m - (rng * low),
                            M + (rng * high))
    normed = norm(s.values)
    c = [colors.rgb2hex(x) for x in plt.cm.get_cmap(cmap)(normed)]
    return ['background-color: %s' % color for color in c]

def highlight_largest_diffs(diffs):
    filled_df = diffs.loc[diffs.sum(axis=1).sort_values(ascending=False).index].fillna(0)
    return filled_df.style.apply(background_gradient, cmap='Reds', m=filled_df.min().min(), M=filled_df.max().max(), low=0, high=2.5)

# %%
highlight_largest_diffs(diffs)
# Out:
# <style  type="text/css" >
#     #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow0_col0 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow0_col1 {
#             background-color:  #fcb095;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow0_col2 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow0_col3 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow0_col4 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow0_col5 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow0_col6 {
#             background-color:  #fcaf93;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow0_col7 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow0_col8 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow1_col0 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow1_col1 {
#             background-color:  #fcbea5;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow1_col2 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow1_col3 {
#             background-color:  #ffefe8;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow1_col4 {
#             background-color:  #fff2eb;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow1_col5 {
#             background-color:  #ffeee6;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow1_col6 {
#             background-color:  #fff2ec;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow1_col7 {
#             background-color:  #fff2ec;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow1_col8 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow2_col0 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow2_col1 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow2_col2 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow2_col3 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow2_col4 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow2_col5 {
#             background-color:  #fee1d3;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow2_col6 {
#             background-color:  #fee2d5;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow2_col7 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow2_col8 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow3_col0 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow3_col1 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow3_col2 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow3_col3 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow3_col4 {
#             background-color:  #fdd1be;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow3_col5 {
#             background-color:  #fff2eb;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow3_col6 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow3_col7 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow3_col8 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow4_col0 {
#             background-color:  #fed9c9;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow4_col1 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow4_col2 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow4_col3 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow4_col4 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow4_col5 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow4_col6 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow4_col7 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow4_col8 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow5_col0 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow5_col1 {
#             background-color:  #fff4ef;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow5_col2 {
#             background-color:  #ffeee7;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow5_col3 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow5_col4 {
#             background-color:  #fff4ee;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow5_col5 {
#             background-color:  #fff3ed;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow5_col6 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow5_col7 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow5_col8 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow6_col0 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow6_col1 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow6_col2 {
#             background-color:  #ffeee6;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow6_col3 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow6_col4 {
#             background-color:  #fff4ee;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow6_col5 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow6_col6 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow6_col7 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow6_col8 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow7_col0 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow7_col1 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow7_col2 {
#             background-color:  #fff4ee;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow7_col3 {
#             background-color:  #fff4ee;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow7_col4 {
#             background-color:  #fff0e9;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow7_col5 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow7_col6 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow7_col7 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow7_col8 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow8_col0 {
#             background-color:  #fff1ea;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow8_col1 {
#             background-color:  #fff3ed;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow8_col2 {
#             background-color:  #fff5f0;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow8_col3 {
#             background-color:  #fff4ef;
#         }    #T_26fc27b6_c1b4_11e8_b625_0c54a51d1a3crow8_col4 {
#             bac
