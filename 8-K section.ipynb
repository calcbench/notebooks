# %%
import calcbench as cb

# %%
cb.document_types()['nonXBRLItemTypes'] # use the arcrole for the document_type argument to cb.document_search
# Out:
# [{'arcrole': 11010,
#   'name': 'Item 1.01 Entry into Agreement',
#   'shortName': 'Item 1.01 Entry into Agreement',
#   'tags': None,
#   'documentType': '8-Ks By Item Type',
#   'longName': 'Item 1.01 Entry into Agreement'},
#  {'arcrole': 11020,
#   'name': 'Item 1.02 Termination of Agreement',
#   'shortName': 'Item 1.02 Termination of Agreement',
#   'tags': None,
#   'documentType': '8-Ks By Item Type',
#   'longName': 'Item 1.02 Termination of Agreement'},
#  {'arcrole': 11030,
#   'name': 'Item 1.03 Bankruptcy/Receivership',
#   'shortName': 'Item 1.03 Bankruptcy/Receivership',
#   'tags': None,
#   'documentType': '8-Ks By Item Type',
#   'longName': 'Item 1.03 Bankruptcy/Receivership'},
#  {'arcrole': 11040,
#   'name': 'Item 1.04 Mine Safety',
#   'shortName': 'Item 1.04 Mine Safety',
#   'tags': None,
#   'documentType': '8-Ks By Item Type',
#   'longName': 'Item 1.04 Mine Safety'},
#  {'arcrole': 12010,
#   'name': 'Item 2.01 Acquisition/Disposition',
# ...

# %%
document_type = 12020 #  'Item 2.02 Results'
docs = cb.document_search(company_identifiers=['adt'], all_history=True, document_type='12020')
for d in docs:
    print('{entity_name}{ticker} {disclosure_type_name} {received_date}'.format(**d))
    print(d.get_contents_text())
# Out:
# ADT Inc.ADT Item 2.02 Results 2019-03-11T16:14:11.81
#
# EX-99.1
# 2
# adt03-11x19ex99x1.htm
# EXHIBIT 99.1
#
#
#
#
#
#
# Exhibit
#
#
# ...
